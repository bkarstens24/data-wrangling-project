# %% [markdown]
# # Spotify Project
#
# **Authors:** Brian Karstens and Christian Kleronomos
# **Last Modified:** 12-09-2024 (created: 11-17-2024)

# %% [markdown]
# **Description:** This project will use a Kaggle dataset containing data of the most popular songs from the 2010's and scrape data from both Spotify using the web developer and Spotify song data themselves.  First the .csv file is loaded in as a dataframe.  Using the songs from the data frame, Spotipy API will find the track ids and generate a url to get to the spotify webpage.  The remainder of this notebook will scrape each individual songs url to retrieve the number of streams the song has.

# %% [markdown]
# <br>

# %% [markdown]
# Import Libraries:

# %%
# !pip install spotipy
# Out:
# Requirement already satisfied: spotipy in /opt/anaconda3/lib/python3.12/site-packages (2.24.0)
# Requirement already satisfied: redis>=3.5.3 in /opt/anaconda3/lib/python3.12/site-packages (from spotipy) (5.2.0)
# Requirement already satisfied: requests>=2.25.0 in /opt/anaconda3/lib/python3.12/site-packages (from spotipy) (2.32.2)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/anaconda3/lib/python3.12/site-packages (from spotipy) (2.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.25.0->spotipy) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.25.0->spotipy) (2024.8.30)

# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from selenium import webdriver
from selenium.webdriver.common.by import By 
from selenium.webdriver.chrome.service import Service 
from webdriver_manager.chrome import ChromeDriverManager 
import time
import random

# %%
songs = pd.read_csv("Spotify_2010_-_2019_Top_100_Songs.csv", encoding='UTF-8')
display(songs)
# Out:
#                                              title              artist  \
# 0                    STARSTRUKK (feat. Katy Perry)               3OH!3
# 1                      My First Kiss (feat. Ke$ha)               3OH!3
# 2                                  I Need A Dollar          Aloe Blacc
# 3    Airplanes (feat. Hayley Williams of Paramore)               B.o.B
# 4                Nothin' on You (feat. Bruno Mars)               B.o.B
# ..                                             ...                 ...
# 995                                     SICKO MODE        Travis Scott
# 996                                      EARFQUAKE  Tyler, The Creator
# 997                      Boasty (feat. Idris Elba)               Wiley
# 998                    Strike a Pose (feat. Aitch)    Young T & Bugsey
# 999      The London (feat. J. Cole & Travis Scott)          Young Thug
#
#        top_genre  year_released       added  bpm  nrgy  dnce  dB  live  val  \
# 0      dance pop           2009  2022‑02‑17  140    81    61  -6    23   23
# 1      dance pop           2010  2022‑02‑17  138    89    68  -4    36   83
# 2       pop soul           2010  2022‑02‑17   95    48    84  -7     9   96
# 3    atl hip hop           2010  2022‑02‑17   93    87    66  -4     4   38
# 4    atl hip hop           2010  2022‑02‑17  104    85    69  -6     9   74
# ..           ...            ...         ...  ...   ...   ...  ..   ...  ...
# 995      hip hop           2018  2020‑06‑22  155    73    83  -4    12   45
# 996      hip hop           2019  2020‑06‑22   80    50    55  -9    80   41
# 997        grime           2019  2020‑06‑22  103    77    89  -5     9   46
# 998    afroswing           2019  2020‑08‑20  138    58    53  -6    10   59
# 999  atl hip hop           2019  2020‑06‑22   98    59    80  -7    13   18
#
#      dur  acous  spch  pop  top_year artist_type
# 0    203      0     6   70      2010         Duo
# 1    192      1     8   68      2010         Duo
# 2    243     20     3   72      2010        Solo
# 3    180     11    12   80      2010        Solo
# 4    268     39     5   79      2010        Solo
# ..   ...    ...   ...  ...       ...         ...
# 995  313      1    22   86      2019        Solo
# 996  190     23     7   85      2019        Solo
# 997  177      1     7   68      2019        Solo
# 998  214      1    10   67      2019         Duo
# 999  200      2    15   75      2019        Solo
#
# [1000 rows x 17 columns]

# %%
client_id = 'e506a46eda964804881d83753da0a954'
client_secret = 'edf5f15c27194c37a3df6e5a7cd37e8d'

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

def get_song_details(song_title, artist_name, year_released):
    query = f"track:{song_title} artist:{artist_name} year:{year_released}"
    result = sp.search(q=query, limit=1, type='track')
    
    if result['tracks']['items']:
        track = result['tracks']['items'][0]
        return {
            'title': track['name'],
            'artist': track['artists'][0]['name'],
            'pop_today': track['popularity'],
            'track_id': track['id'],
            'url': track['external_urls']['spotify']
        }
    else:
        return None

song_details = []
for _, row in songs.iterrows():
    title = row['title']
    artist = row['artist']  
    year = row['year_released'] 
    details = get_song_details(title, artist, year)
    if details:
        song_details.append(details)

songs_df = pd.DataFrame(song_details)
display(songs_df)
# Out:
#                                              title              artist  \
# 0                    STARSTRUKK (feat. Katy Perry)               3OH!3
# 1                      My First Kiss (feat. Ke$ha)               3OH!3
# 2                                  I Need A Dollar          Aloe Blacc
# 3    Airplanes (feat. Hayley Williams of Paramore)               B.o.B
# 4                Nothin' on You (feat. Bruno Mars)               B.o.B
# ..                                             ...                 ...
# 985                                     SICKO MODE        Travis Scott
# 986                                      EARFQUAKE  Tyler, The Creator
# 987                      Boasty (feat. Idris Elba)               Wiley
# 988                    Strike a Pose (feat. Aitch)    Young T & Bugsey
# 989      The London (feat. J. Cole & Travis Scott)          Young Thug
#
#      pop_today                track_id  \
# 0           62  1hBM2D1ULT3aeKuddSwPsK
# 1           59  17tDv8WA8IhqE8qzuQn707
# 2           67  3oUphdZVPyrsprZ8FgbmQS
# 3           73  6lV2MSQmRIkycDScNtrBXO
# 4           76  59dLtGBS26x7kc0rHbaPrq
# ..         ...                     ...
# 985         81  2xLMifQCjDGFmkHkpNLD9h
# 986         82  5hVghJ4KaYES3BFUATCYn0
# 987         59  5X5YDBavdU5RjYMlxqwlCm
# 988         51  23GvTfcGK454ppLsts3W44
# 989         65  3s4mrPrEFFPF0LmAfutW0n
#
#                                                    url
# 0    https://open.spotify.com/track/1hBM2D1ULT3aeKu...
# 1    https://open.spotify.com/track/17tDv8WA8IhqE8q...
# 2    https://open.spotify.com/track/3oUphdZVPyrsprZ...
# 3    https://open.spotify.com/track/6lV2MSQmRIkycDS...
# 4    https://open.spotify.com/track/59dLtGBS26x7kc0...
# ..                                                 ...
# 985  https://open.spotify.com/track/2xLMifQCjDGFmkH...
# 986  https://open.spotify.com/track/5hVghJ4KaYES3BF...
# 987  https://open.spotify.com/track/5X5YDBavdU5RjYM...
# 988  https://open.spotify.com/track/23GvTfcGK454ppL...
# 989  https://open.spotify.com/track/3s4mrPrEFFPF0Lm...
#
# [990 rows x 5 columns]

# %%
songs_df.to_csv('api_songs.csv', encoding = 'UTF-8', index = False)
songs.to_csv('tophits.csv', encoding='UTF-8', index = False)

# %%
tophits = pd.read_csv('tophits.csv', encoding='UTF-8')
apisongs = pd.read_csv('api_songs.csv', encoding= 'UTF-8')

display(tophits)
display(apisongs)
# Out:
#                                              title              artist  \
# 0                    STARSTRUKK (feat. Katy Perry)               3OH!3
# 1                      My First Kiss (feat. Ke$ha)               3OH!3
# 2                                  I Need A Dollar          Aloe Blacc
# 3    Airplanes (feat. Hayley Williams of Paramore)               B.o.B
# 4                Nothin' on You (feat. Bruno Mars)               B.o.B
# ..                                             ...                 ...
# 995                                     SICKO MODE        Travis Scott
# 996                                      EARFQUAKE  Tyler, The Creator
# 997                      Boasty (feat. Idris Elba)               Wiley
# 998                    Strike a Pose (feat. Aitch)    Young T & Bugsey
# 999      The London (feat. J. Cole & Travis Scott)          Young Thug
#
#        top_genre  year_released       added  bpm  nrgy  dnce  dB  live  val  \
# 0      dance pop           2009  2022‑02‑17  140    81    61  -6    23   23
# 1      dance pop           2010  2022‑02‑17  138    89    68  -4    36   83
# 2       pop soul           2010  2022‑02‑17   95    48    84  -7     9   96
# 3    atl hip hop           2010  2022‑02‑17   93    87    66  -4     4   38
# 4    atl hip hop           2010  2022‑02‑17  104    85    69  -6     9   74
# ..           ...            ...         ...  ...   ...   ...  ..   ...  ...
# 995      hip hop           2018  2020‑06‑22  155    73    83  -4    12   45
# 996      hip hop           2019  2020‑06‑22   80    50    55  -9    80   41
# 997        grime           2019  2020‑06‑22  103    77    89  -5     9   46
# 998    afroswing           2019  2020‑08‑20  138    58    53  -6    10   59
# 999  atl hip hop           2019  2020‑06‑22   98    59    80  -7    13   18
#
#      dur  acous  spch  pop  top_year artist_type
# 0    203      0     6   70      2010         Duo
# 1    192      1     8   68      2010         Duo
# 2    243     20     3   72      2010        Solo
# 3    180     11    12   80      2010        Solo
# 4    268     39     5   79      2010        Solo
# ..   ...    ...   ...  ...       ...         ...
# 995  313      1    22   86      2019        Solo
# 996  190     23     7   85      2019        Solo
# 997  177      1     7   68      2019        Solo
# 998  214      1    10   67      2019         Duo
# 999  200      2    15   75      2019        Solo
#
# [1000 rows x 17 columns]
#                                              title              artist  \
# 0                    STARSTRUKK (feat. Katy Perry)               3OH!3
# 1                      My First Kiss (feat. Ke$ha)               3OH!3
# 2                                  I Need A Dollar          Aloe Blacc
# 3    Airplanes (feat. Hayley Williams of Paramore)               B.o.B
# 4                Nothin' on You (feat. Bruno Mars)               B.o.B
# ..                                             ...                 ...
# 985                                     SICKO MODE        Travis Scott
# 986                                      EARFQUAKE  Tyler, The Creator
# 987                      Boasty (feat. Idris Elba)               Wiley
# 988                    Strike a Pose (feat. Aitch)    Young T & Bugsey
# 989      The London (feat. J. Cole & Travis Scott)          Young Thug
#
#      pop_today                track_id  \
# 0           62  1hBM2D1ULT3aeKuddSwPsK
# 1           59  17tDv8WA8IhqE8qzuQn707
# 2           67  3oUphdZVPyrsprZ8FgbmQS
# 3           73  6lV2MSQmRIkycDScNtrBXO
# 4           76  59dLtGBS26x7kc0rHbaPrq
# ..         ...                     ...
# 985         81  2xLMifQCjDGFmkHkpNLD9h
# 986         82  5hVghJ4KaYES3BFUATCYn0
# 987         59  5X5YDBavdU5RjYMlxqwlCm
# 988         51  23GvTfcGK454ppLsts3W44
# 989         65  3s4mrPrEFFPF0LmAfutW0n
#
#                                                    url
# 0    https://open.spotify.com/track/1hBM2D1ULT3aeKu...
# 1    https://open.spotify.com/track/17tDv8WA8IhqE8q...
# 2    https://open.spotify.com/track/3oUphdZVPyrsprZ...
# 3    https://open.spotify.com/track/6lV2MSQmRIkycDS...
# 4    https://open.spotify.com/track/59dLtGBS26x7kc0...
# ..                                                 ...
# 985  https://open.spotify.com/track/2xLMifQCjDGFmkH...
# 986  https://open.spotify.com/track/5hVghJ4KaYES3BF...
# 987  https://open.spotify.com/track/5X5YDBavdU5RjYM...
# 988  https://open.spotify.com/track/23GvTfcGK454ppL...
# 989  https://open.spotify.com/track/3s4mrPrEFFPF0Lm...
#
# [990 rows x 5 columns]

# %%
# function to scroll from the top to the bottom of the web page
def random_scroll(browser, total_wait_time):
    # get the total height of the page
    total_height = browser.execute_script("return document.body.scrollHeight")
    
    # number of steps to scroll (you can adjust this number)
    scroll_steps = random.randint(2, 10) # randomize how many scroll steps we will use
    
    # calculate the height to scroll on each step
    scroll_increment = total_height // scroll_steps

    # calculate the total time available for scrolling each step
    time_per_step = total_wait_time / scroll_steps
    
    # random scrolling across time
    for step in range(scroll_steps):
        # scroll by the increment (dividing total height by number of steps)
        browser.execute_script(f"window.scrollBy(0, {scroll_increment});")
        
        # random wait time between scrolls to simulate varying speed
        random_wait = random.uniform(0.5 * time_per_step, 1.5 * time_per_step)  # randomize the wait within a range
        time.sleep(random_wait)
        
    # final scroll to make sure you are at the very bottom (in case it didn't exactly match)
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# %%
browser = webdriver.Chrome()

titles = []
artists = []
streams = []


for i in range(0,100):
    track_id = apisongs.iloc[i]['track_id']
    url = f"https://open.spotify.com/track/{track_id}"
    print(url)
    
    browser.get(url)
    browser.maximize_window()

    total_wait_time = random.uniform(7, 12)  
    random_scroll(browser, total_wait_time)

    title_elements = browser.find_elements(By.CSS_SELECTOR, 'h1.encore-text.encore-text-headline-large[data-encore-id="text"]')
    for title in title_elements:
        titles.append(title.text)

    artist_elements = browser.find_elements(By.CSS_SELECTOR, 'a[data-testid="creator-link"]')
    for artist_elem in artist_elements:
        artists.append(artist_elem.text)  

    streams_elements = browser.find_elements(By.CSS_SELECTOR, 'span[data-testid="playcount"]')
    for streams_elem in streams_elements:
        streams.append(streams_elem.text)  

    print(f"Song {track_id} done, {[i]}")

    time.sleep(random.randint(2,4))

browser.close()

print("-"* 30)
print(f"# of Titles: {len(titles)}")  
print(f"# of Artists: {len(artists)}")  
print(f"# of Streams: {len(streams)}")
# Out:
# https://open.spotify.com/track/1hBM2D1ULT3aeKuddSwPsK
# Song 1hBM2D1ULT3aeKuddSwPsK done, [0]
# https://open.spotify.com/track/17tDv8WA8IhqE8qzuQn707
# Song 17tDv8WA8IhqE8qzuQn707 done, [1]
# https://open.spotify.com/track/3oUphdZVPyrsprZ8FgbmQS
# Song 3oUphdZVPyrsprZ8FgbmQS done, [2]
# https://open.spotify.com/track/6lV2MSQmRIkycDScNtrBXO
# Song 6lV2MSQmRIkycDScNtrBXO done, [3]
# https://open.spotify.com/track/59dLtGBS26x7kc0rHbaPrq
# Song 59dLtGBS26x7kc0rHbaPrq done, [4]
# https://open.spotify.com/track/5uHYcK0nbEYgRaFTY5BqnP
# Song 5uHYcK0nbEYgRaFTY5BqnP done, [5]
# https://open.spotify.com/track/7vWFaMq63AwkFDhS2OAg5u
# Song 7vWFaMq63AwkFDhS2OAg5u done, [6]
# https://open.spotify.com/track/0oJMv049q8hEkes9w0L1J4
# Song 0oJMv049q8hEkes9w0L1J4 done, [7]
# https://open.spotify.com/track/161DnLWsx1i3u1JT05lzqU
# Song 161DnLWsx1i3u1JT05lzqU done, [8]
# https://open.spotify.com/track/7BqBn9nzAq8spo5e7cZ0dJ
# Song 7BqBn9nzAq8spo5e7cZ0dJ done, [9]
# https://open.spotify.com/track/09ZcYBGFX16X8GMDrvqQwt
# Song 09ZcYBGFX16X8GMDrvqQwt done, [81]
# https://open.spotify.com/track/4kPf4MbDp81GfVHLISdByL
# Song 4kPf4MbDp81GfVHLISdByL done, [82]
# https://open.spotify.com/track/5BIgbz2Dy7X2I0bnkKH9Mb
# Song 5BIgbz2Dy7X2I0bnkKH9Mb done, [83]
# https://open.spotify.com/track/2DHc2e5bBn4UzY0ENVFrUl
# Song 2DHc2e5bBn4UzY0ENVFrUl done, [84]
# https://open.spotify.com/track/360UM2DaiHZPRu0EsrOvMp
# Song 360UM2DaiHZPRu0EsrOvMp done, [85]
# https://open.spotify.com/track/4Q4K8fikwOmZYmz82Wco4w
# Song 4Q4K8fikwOmZYmz82Wco4w done, [86]
# https://open.spotify.com/track/61HQWI1Woxup7CnGwVUsdI
# Song 61HQWI1Woxup7CnGwVUsdI done, [87]
# https://open.spotify.com/track/4HlFJV71xXKIGcU3kRyttv
# Song 4HlFJV71xXKIGcU3kRyttv done, [88]
# https://open.spotify.com/track/2qPUnoasNe4Ep43emVXEig
# Song 2qPUnoasNe4Ep43emVXEig done, [89]
# https://open.spotify.com/track/4AYX69oFP3UOS1CFmV9UfO
# Song 4AYX69oFP3UOS1CFmV9UfO done, [90]
# https://open.spotify.com/track/2fQ6sBFWaLv2Gxos4igHLy
# Song 2fQ6sBFWaLv2Gxos4igHLy done, [91]
# https://open.spotify.com/track/4iZxeyibg6w4EFCOoAQ6Eh
# Song 4iZxeyibg6w4EFCOoAQ6Eh done, [92]
# https://open.spotify.com/track/4356Typ82hUiFAynbLYbPn
# Song 4356Typ82hUiFAynbLYbPn done, [93]
# https://open.spotify.com/track/1bM50INir8voAkVoKuvEUI
# Song 1bM50INir8voAkVoKuvEUI done, [94]
# https://open.spotify.com/track/030OCtLMrljNhp8OWHBWW3
# Song 030OCtLMrljNhp8OWHBWW3 done, [95]
# https://open.spotify.com/track/03tqyYWC9Um2ZqU0ZN849H
# Song 03tqyYWC9Um2ZqU0ZN849H done, [96]
# https://open.spotify.com/track/37dYAkMa4lzRCH6kDbMT1L
# Song 37dYAkMa4lzRCH6kDbMT1L done, [97]
# https://open.spotify.com/track/3iL2l5gUqyPS6vDwJFgJTR
# Song 3iL2l5gUqyPS6vDwJFgJTR done, [98]
# https://open.spotify.com/track/1c8gk2PeTE04A1pIDH9YMk
# Song 1c8gk2PeTE04A1pIDH9YMk done, [99]
# ------------------------------
# # of Titles: 100
# # of Artists: 100
# # of Streams: 100

# %%
chunk = pd.DataFrame({'title': titles, 'artist': artists, 'streams': streams})
chunk.to_csv('chunk_raw.csv', encoding = 'UTF-8', index=False)
display(chunk)
# Out:
#                                             title             artist  \
# 0                   STARSTRUKK (feat. Katy Perry)              3OH!3
# 1                     My First Kiss (feat. Ke$ha)              3OH!3
# 2                                 I Need A Dollar         Aloe Blacc
# 3   Airplanes (feat. Hayley Williams of Paramore)              B.o.B
# 4               Nothin' on You (feat. Bruno Mars)              B.o.B
# ..                                            ...                ...
# 95                       Hey Daddy (Daddy's Home)              USHER
# 96            No Hands (feat. Roscoe Dash & Wale)  Waka Flocka Flame
# 97                   We No Speak Americano (Edit)    Yolanda Be Cool
# 98                                        BedRock        Young Money
# 99                            Rolling in the Deep              Adele
#
#           streams
# 0     160,363,103
# 1     126,408,708
# 2     282,228,422
# 3     843,380,081
# 4     684,014,150
# ..            ...
# 95    285,641,365
# 96    715,558,832
# 97    158,225,136
# 98    368,521,660
# 99  1,981,838,182
#
# [100 rows x 3 columns]

# %%
browser = webdriver.Chrome()

titles1 = []
artists1 = []  
streams1 = []


for i in range(100,200):
    track_id = apisongs.iloc[i]['track_id']
    url = f"https://open.spotify.com/track/{track_id}"
    print(url)

    browser.get(url)

    total_wait_time = random.uniform(8, 12)  
    random_scroll(browser, total_wait_time)

    title_elements = browser.find_elements(By.CSS_SELECTOR, 'h1.encore-text.encore-text-headline-large[data-encore-id="text"]')
    for title in title_elements:
        titles1.append(title.text)

    artist_elements = browser.find_elements(By.CSS_SELECTOR, 'a[data-testid="creator-link"]')
    for artist_elem in artist_elements:
        artists1.append(artist_elem.text)  

    streams_elements = browser.find_elements(By.CSS_SELECTOR, 'span[data-testid="playcount"]')
    for streams_elem in streams_elements:
        streams1.append(streams_elem.text)  

    print(f"Song {track_id} done, {[i]}")

    time.sleep(random.randint(2,5))

browser.close()

print("-"* 30)
print(f"# of Titles: {len(titles1)}") 
print(f"# of Artists: {len(artists1)}")  
print(f"# of Streams: {len(streams1)}")
# Out:
# https://open.spotify.com/track/73CMRj62VK8nUS4ezD2wvi
# Song 73CMRj62VK8nUS4ezD2wvi done, [100]
# https://open.spotify.com/track/6HTprulGfeFVrLLvfi3t8a
# Song 6HTprulGfeFVrLLvfi3t8a done, [101]
# https://open.spotify.com/track/2z4U9d5OAA4YLNXoCgioxo
# Song 2z4U9d5OAA4YLNXoCgioxo done, [102]
# https://open.spotify.com/track/5zpDHEU12zATwLGvozxPw2
# Song 5zpDHEU12zATwLGvozxPw2 done, [103]
# https://open.spotify.com/track/1z6WtY7X4HQJvzxC4UgkSf
# Song 1z6WtY7X4HQJvzxC4UgkSf done, [104]
# https://open.spotify.com/track/3lBRNqXjPp2j3JMTCXDTNO
# Song 3lBRNqXjPp2j3JMTCXDTNO done, [105]
# https://open.spotify.com/track/4RL77hMWUq35NYnPLXBpih
# Song 4RL77hMWUq35NYnPLXBpih done, [106]
# https://open.spotify.com/track/3JA9Jsuxr4xgHXEawAdCp4
# Song 3JA9Jsuxr4xgHXEawAdCp4 done, [107]
# https://open.spotify.com/track/0gY2iq0xJPRoIB1PScKSw4
# Song 0gY2iq0xJPRoIB1PScKSw4 done, [108]
# https://open.spotify.com/track/35KiiILklye1JRRctaLUb4
# Song 35KiiILklye1JRRctaLUb4 done, [109]
# https://open.spotify.com/track/5cCAZS9VhLGEDV4NCfieeg
# Song 5cCAZS9VhLGEDV4NCfieeg done, [110]
# https://open.spotify.com/track/38iU2jg98IZZEIJPrP7aWD
# Song 38iU2jg98IZZEIJPrP7aWD done, [111]
# https://open.spotify.com/track/2tJulUYLDKOg9XrtVkMgcJ
# Song 2tJulUYLDKOg9XrtVkMgcJ done, [112]
# https://open.spotify.com/track/22PMfvdz35fFKYnJyMn077
# Song 22PMfvdz35fFKYnJyMn077 done, [113]
# https://open.spotify.com/track/1ExfPZEiahqhLyajhybFeS
# Song 1ExfPZEiahqhLyajhybFeS done, [114]
# https://open.spotify.com/track/36cmM3MBMWWCFIiQ90U4J8
# Song 36cmM3MBMWWCFIiQ90U4J8 done, [115]
# https://open.spotify.com/track/04OxTCLGgDKfO0MMA2lcxv
# Song 04OxTCLGgDKfO0MMA2lcxv done, [116]
# https://open.spotify.com/track/2hi6E31kMuHTcG0B18N7jP
# https://open.spotify.com/track/0MJ7MlBHBVQxzwHz5bfCZk
# Song 0MJ7MlBHBVQxzwHz5bfCZk done, [187]
# https://open.spotify.com/track/0laYHRpNTS6i8FXdupHkJ4
# Song 0laYHRpNTS6i8FXdupHkJ4 done, [188]
# https://open.spotify.com/track/3TcL0dyCMyr0kyTTc4NLgI
# Song 3TcL0dyCMyr0kyTTc4NLgI done, [189]
# https://open.spotify.com/track/0R7YVi7w41Dr9jU5vblAok
# Song 0R7YVi7w41Dr9jU5vblAok done, [190]
# https://open.spotify.com/track/65hRZOQkVjmBdusz1N7aOv
# Song 65hRZOQkVjmBdusz1N7aOv done, [191]
# https://open.spotify.com/track/089vxHEH64AKLKhokNXEJx
# Song 089vxHEH64AKLKhokNXEJx done, [192]
# https://open.spotify.com/track/4u26EevCNXMhlvE1xFBJwX
# Song 4u26EevCNXMhlvE1xFBJwX done, [193]
# https://open.spotify.com/track/5yDL13y5giogKs2fSNf7sj
# Song 5yDL13y5giogKs2fSNf7sj done, [194]
# https://open.spotify.com/track/0aBKFfdyOD1Ttvgv0cfjjJ
# Song 0aBKFfdyOD1Ttvgv0cfjjJ done, [195]
# https://open.spotify.com/track/03tqyYWC9Um2ZqU0ZN849H
# Song 03tqyYWC9Um2ZqU0ZN849H done, [196]
# https://open.spotify.com/track/5A6OHHy73AR5tLxgTc98zz
# Song 5A6OHHy73AR5tLxgTc98zz done, [197]
# https://open.spotify.com/track/53DB6LJV9B8sz0p1s6tlGS
# Song 53DB6LJV9B8sz0p1s6tlGS done, [198]
# https://open.spotify.com/track/6VObnIkLVruX4UVyxWhlqm
# Song 6VObnIkLVruX4UVyxWhlqm done, [199]
# ------------------------------
# # of Titles: 100
# # of Artists: 100
# # of Streams: 100

# %%
chunk1 = pd.DataFrame({'title': titles1, 'artist': artists1, 'streams': streams1})
chunk1.to_csv('chunk1_raw.csv', encoding = 'UTF-8', index=False)
display(chunk1)
# Out:
#                                   title             artist        streams
# 0                  Set Fire to the Rain              Adele  1,819,493,514
# 1             Mr. Saxobeat - Radio Edit     Alexandra Stan    642,966,652
# 2                         What the Hell      Avril Lavigne    430,331,054
# 3                              Lighters     Bad Meets Evil    269,488,030
# 4                           Love On Top            Beyoncé    679,659,501
# ..                                  ...                ...            ...
# 95      More - RedOne Jimmy Joker Remix              USHER    207,271,291
# 96  No Hands (feat. Roscoe Dash & Wale)  Waka Flocka Flame    717,551,513
# 97                     Black and Yellow        Wiz Khalifa    684,219,442
# 98                              Roll Up        Wiz Khalifa    167,691,228
# 99                              Skyfall              Adele    893,360,241
#
# [100 rows x 3 columns]

# %%
browser = webdriver.Chrome()

titles2 = []
artists2 = []  
streams2 = []


for i in range(200,300):
    track_id = apisongs.iloc[i]['track_id']
    url = f"https://open.spotify.com/track/{track_id}"
    print(url)
    
    browser.get(url)
    browser.maximize_window()

    total_wait_time = random.uniform(7, 12)  
    random_scroll(browser, total_wait_time)

    title_elements = browser.find_elements(By.CSS_SELECTOR, 'h1.encore-text.encore-text-headline-large[data-encore-id="text"]')
    for title in title_elements:
        titles2.append(title.text)

    artist_elements = browser.find_elements(By.CSS_SELECTOR, 'a[data-testid="creator-link"]')
    for artist_elem in artist_elements:
        artists2.append(artist_elem.text)  

    streams_elements = browser.find_elements(By.CSS_SELECTOR, 'span[data-testid="playcount"]')
    for streams_elem in streams_elements:
        streams2.append(streams_elem.text)  

    print(f"Song {track_id} done, {[i]}")

    time.sleep(random.randint(2,4))

browser.close()

print("-"* 30)
print(f"# of Titles: {len(titles2)}")  
print(f"# of Artists: {len(artists2)}")  
print(f"# of Streams: {len(streams2)}")
# Out:
# https://open.spotify.com/track/2A73XBDBQgmdXO8VsXPWIs
# Song 2A73XBDBQgmdXO8VsXPWIs done, [200]
# https://open.spotify.com/track/5pVk15sR3OgIeKBKqG9jWw
# Song 5pVk15sR3OgIeKBKqG9jWw done, [201]
# https://open.spotify.com/track/4sK96UnGx3NjBaqvfTG2dm
# Song 4sK96UnGx3NjBaqvfTG2dm done, [202]
# https://open.spotify.com/track/3n69hLUdIsSa1WlRmjMZlW
# Song 3n69hLUdIsSa1WlRmjMZlW done, [203]
# https://open.spotify.com/track/6c5QZx2v9753q26g1Fvo2F
# Song 6c5QZx2v9753q26g1Fvo2F done, [204]
# https://open.spotify.com/track/68rcszAg5pbVaXVvR7LFNh
# Song 68rcszAg5pbVaXVvR7LFNh done, [205]
# https://open.spotify.com/track/5UqCQaDshqbIk3pkhy4Pjg
# Song 5UqCQaDshqbIk3pkhy4Pjg done, [206]
# https://open.spotify.com/track/06h3McKzmxS8Bx58USHiMq
# Song 06h3McKzmxS8Bx58USHiMq done, [207]
# https://open.spotify.com/track/7mDKRYiqejoHzP7dQGxLys
# Song 7mDKRYiqejoHzP7dQGxLys done, [208]
# https://open.spotify.com/track/28GUjBGqZVcAV4PHSYzkj2
# Song 28GUjBGqZVcAV4PHSYzkj2 done, [209]
# https://open.spotify.com/track/3w3y8KPTfNeOKPiqUTakBh
# Song 3w3y8KPTfNeOKPiqUTakBh done, [210]
# https://open.spotify.com/track/0RUGuh2uSNFJpGMSsD1F5C
# Song 0RUGuh2uSNFJpGMSsD1F5C done, [211]
# https://open.spotify.com/track/1gihuPhrLraKYrJMAEONyc
# Song 1gihuPhrLraKYrJMAEONyc done, [212]
# https://open.spotify.com/track/4wkQmYpAaMe41Rc3sYZ7Vz
# Song 4wkQmYpAaMe41Rc3sYZ7Vz done, [213]
# https://open.spotify.com/track/7B1Dl3tXqySkB8OPEwVvSu
# Song 7B1Dl3tXqySkB8OPEwVvSu done, [214]
# https://open.spotify.com/track/3TGRqZ0a2l1LRblBkJoaDx
# Song 3TGRqZ0a2l1LRblBkJoaDx done, [215]
# https://open.spotify.com/track/0vFMQi8ZnOM2y8cuReZTZ2
# Song 0vFMQi8ZnOM2y8cuReZTZ2 done, [216]
# https://open.spotify.com/track/6E11E0lT5Zy7yb6iT3y8DN
# Song 6E11E0lT5Zy7yb6iT3y8DN done, [217]
# https://open.spotify.com/track/1RMRkCn07y2xtBip9DzwmC
# Song 1RMRkCn07y2xtBip9DzwmC done, [218]
# https://open.spotify.com/track/6nek1Nin9q48AVZcWs9e9D
# Song 6nek1Nin9q48AVZcWs9e9D done, [219]
# https://open.spotify.com/track/4HXOBjwv2RnLpGG4xWOO6N
# Song 4HXOBjwv2RnLpGG4xWOO6N done, [220]
# https://open.spotify.com/track/6JOlNkT0QdHeZB0wPbI9IR
# Song 6JOlNkT0QdHeZB0wPbI9IR done, [221]
# https://open.spotify.com/track/1pbHy9VBpSyZh56xuujZz0
# Song 1pbHy9VBpSyZh56xuujZz0 done, [222]
# https://open.spotify.com/track/1DunhgeZSEgWiIYbHqXl0c
# Song 1DunhgeZSEgWiIYbHqXl0c done, [223]
# https://open.spotify.com/track/4KSnjqkg5wskKGEZg7sD1y
# https://open.spotify.com/track/4vULFpGH9sCBdCfCC6p3Xo
# Song 4vULFpGH9sCBdCfCC6p3Xo done, [294]
# https://open.spotify.com/track/5pyVqlqThcxI7tPDjHIzPh
# Song 5pyVqlqThcxI7tPDjHIzPh done, [295]
# https://open.spotify.com/track/3e0yTP5trHBBVvV32jwXqF
# Song 3e0yTP5trHBBVvV32jwXqF done, [296]
# https://open.spotify.com/track/1ms5tNNdPouTtcD2oVF9Oz
# Song 1ms5tNNdPouTtcD2oVF9Oz done, [297]
# https://open.spotify.com/track/2OQJKTtrH482waGFmOfJni
# Song 2OQJKTtrH482waGFmOfJni done, [298]
# https://open.spotify.com/track/4X5f3vT8MRuXF68pfjNte5
# Song 4X5f3vT8MRuXF68pfjNte5 done, [299]
# ------------------------------
# # of Titles: 100
# # of Artists: 100
# # of Streams: 100

# %%
chunk2 = pd.DataFrame({'title': titles2, 'artist': artists2, 'streams': streams2})
chunk2.to_csv('chunk2_raw.csv', encoding = 'UTF-8', index=False)

# %%
browser = webdriver.Chrome()

titles3 = []
artists3 = []  
streams3 = []


for i in range(300,400):
    track_id = apisongs.iloc[i]['track_id']
    url = f"https://open.spotify.com/track/{track_id}"
    print(url)

    browser.get(url)
    browser.maximize_window()

    total_wait_time = random.uniform(9, 13)  
    random_scroll(browser, total_wait_time)

    title_elements = browser.find_elements(By.CSS_SELECTOR, 'h1.encore-text.encore-text-headline-large[data-encore-id="text"]')
    for title in title_elements:
        titles3.append(title.text)

    artist_elements = browser.find_elements(By.CSS_SELECTOR, 'a[data-testid="creator-link"]')
    for artist_elem in artist_elements:
        artists3.append(artist_elem.text)  

    streams_elements = browser.find_elements(By.CSS_SELECTOR, 'span[data-testid="playcount"]')
    for streams_elem in streams_elements:
        streams3.append(streams_elem.text)  

    print(f"Song {track_id} done, {[i]}")

    time.sleep(random.randint(5,7)) 

browser.close()

print("-"* 30)
print(f"# of Titles: {len(titles3)}") 
print(f"# of Artists: {len(artists3)}")  
print(f"# of Streams: {len(streams3)}")
# Out:
# https://open.spotify.com/track/086myS9r57YsLbJpU0TgK9
# Song 086myS9r57YsLbJpU0TgK9 done, [300]
# https://open.spotify.com/track/5FVd6KXrgO9B3JPmC8OPst
# Song 5FVd6KXrgO9B3JPmC8OPst done, [301]
# https://open.spotify.com/track/06EL94D0TA27Ik0Ke5usbj
# Song 06EL94D0TA27Ik0Ke5usbj done, [302]
# https://open.spotify.com/track/0nrRP2bk19rLc0orkWPQk2
# Song 0nrRP2bk19rLc0orkWPQk2 done, [303]
# https://open.spotify.com/track/591nHHHzZl1NLt9PMKpinM
# Song 591nHHHzZl1NLt9PMKpinM done, [304]
# https://open.spotify.com/track/0qwcGscxUHGZTgq0zcaqk1
# Song 0qwcGscxUHGZTgq0zcaqk1 done, [305]
# https://open.spotify.com/track/7ueP5u2qkdZbIPN2YA6LR0
# Song 7ueP5u2qkdZbIPN2YA6LR0 done, [306]
# https://open.spotify.com/track/01XFgRZfZI7oBagNf1Loml
# Song 01XFgRZfZI7oBagNf1Loml done, [307]
# https://open.spotify.com/track/3gbBpTdY8lnQwqxNCcf795
# Song 3gbBpTdY8lnQwqxNCcf795 done, [308]
# https://open.spotify.com/track/7BNDyzwDboNRR2wmd7GSew
# Song 7BNDyzwDboNRR2wmd7GSew done, [309]
# https://open.spotify.com/track/5yIiXdLRE85OBiQmCaUenq
# Song 5yIiXdLRE85OBiQmCaUenq done, [310]
# https://open.spotify.com/track/5xvUgoVED1F4mBu8FL0HaW
# Song 5xvUgoVED1F4mBu8FL0HaW done, [311]
# https://open.spotify.com/track/3KliPMvk1EvFZu9cvkj8p1
# Song 3KliPMvk1EvFZu9cvkj8p1 done, [312]
# https://open.spotify.com/track/3w3y8KPTfNeOKPiqUTakBh
# Song 3w3y8KPTfNeOKPiqUTakBh done, [313]
# https://open.spotify.com/track/0nJW01T7XtvILxQgC5J7Wh
# https://open.spotify.com/track/6ce41JVa6KFaryfmC2bu2W
# Song 6ce41JVa6KFaryfmC2bu2W done, [384]
# https://open.spotify.com/track/3Z1kZKYfRC8iRXnYeC5sCJ
# Song 3Z1kZKYfRC8iRXnYeC5sCJ done, [385]
# https://open.spotify.com/track/44Ljlpy44mHvLJxcYUvTK0
# Song 44Ljlpy44mHvLJxcYUvTK0 done, [386]
# https://open.spotify.com/track/0DwClY2t9YAWHBROMIgrXb
# Song 0DwClY2t9YAWHBROMIgrXb done, [387]
# https://open.spotify.com/track/2QjOHCTQ1Jl3zawyYOpxh6
# Song 2QjOHCTQ1Jl3zawyYOpxh6 done, [388]
# https://open.spotify.com/track/4Hsn8y4PcSU6bm9bLB1gwy
# Song 4Hsn8y4PcSU6bm9bLB1gwy done, [389]
# https://open.spotify.com/track/3JvKfv6T31zO0ini8iNItO
# Song 3JvKfv6T31zO0ini8iNItO done, [390]
# https://open.spotify.com/track/5yhKaacMZGRo4s6evJx9vk
# Song 5yhKaacMZGRo4s6evJx9vk done, [391]
# https://open.spotify.com/track/2iJuuzV8P9Yz0VSurttIV5
# Song 2iJuuzV8P9Yz0VSurttIV5 done, [392]
# https://open.spotify.com/track/01TuObJVd7owWchVRuQbQw
# Song 01TuObJVd7owWchVRuQbQw done, [393]
# https://open.spotify.com/track/5HOpkTTVcmZHnthgyxrIL8
# Song 5HOpkTTVcmZHnthgyxrIL8 done, [394]
# https://open.spotify.com/track/60wwxj6Dd9NJlirf84wr2c
# Song 60wwxj6Dd9NJlirf84wr2c done, [395]
# https://open.spotify.com/track/1gugDOSMREb34Xo0c1PlxM
# Song 1gugDOSMREb34Xo0c1PlxM done, [396]
# https://open.spotify.com/track/1JCCdiru7fhstOIF4N7WJC
# Song 1JCCdiru7fhstOIF4N7WJC done, [397]
# https://open.spotify.com/track/0YzCQcsgj6KqwBHVx1mZrH
# Song 0YzCQcsgj6KqwBHVx1mZrH done, [398]
# https://open.spotify.com/track/77ZDYZaY5ppRrVqZOMUF2P
# Song 77ZDYZaY5ppRrVqZOMUF2P done, [399]
# ------------------------------
# # of Titles: 100
# # of Artists: 100
# # of Streams: 100

# %%
chunk3 = pd.DataFrame({'title': titles3, 'artist': artists3, 'streams': streams3})
chunk3.to_csv('chunk3_raw.csv', encoding = 'UTF-8', index=False)

# %%
browser = webdriver.Chrome()

titles4 = []
artists4 = []  
streams4 = []


for i in range(400,500):
    track_id = apisongs.iloc[i]['track_id']
    url = f"https://open.spotify.com/track/{track_id}"
    print(url)
    
    browser.get(url)
    browser.maximize_window()

    total_wait_time = random.uniform(10, 13)  
    random_scroll(browser, total_wait_time)

    title_elements = browser.find_elements(By.CSS_SELECTOR, 'h1.encore-text.encore-text-headline-large[data-encore-id="text"]')
    for title in title_elements:
        titles4.append(title.text)

    artist_elements = browser.find_elements(By.CSS_SELECTOR, 'a[data-testid="creator-link"]')
    for artist_elem in artist_elements:
        artists4.append(artist_elem.text)  

    streams_elements = browser.find_elements(By.CSS_SELECTOR, 'span[data-testid="playcount"]')
    for streams_elem in streams_elements:
        streams4.append(streams_elem.text)  
        
    print(f"Song {track_id} done, {[i]}")

    time.sleep(random.randint(6,7))

browser.close()

print("-"* 30)
print(f"# of Titles: {len(titles4)}")  
print(f"# of Artists: {len(artists4)}")  
print(f"# of Streams: {len(streams4)}")
# Out:
# https://open.spotify.com/track/5Hroj5K7vLpIG4FNCRIjbP
# Song 5Hroj5K7vLpIG4FNCRIjbP done, [400]
# https://open.spotify.com/track/5J4ZkQpzMUFojo1CtAZYpn
# Song 5J4ZkQpzMUFojo1CtAZYpn done, [401]
# https://open.spotify.com/track/7vS3Y0IKjde7Xg85LWIEdP
# Song 7vS3Y0IKjde7Xg85LWIEdP done, [402]
# https://open.spotify.com/track/3qqho4PnTn3zlMPBzWhFFD
# Song 3qqho4PnTn3zlMPBzWhFFD done, [427]
# https://open.spotify.com/track/2ixsaeFioXJmMgkkbd4uj1
# Song 2ixsaeFioXJmMgkkbd4uj1 done, [428]
# https://open.spotify.com/track/2vzMWO0T008m86yDnXwkII
# Song 2vzMWO0T008m86yDnXwkII done, [429]
# https://open.spotify.com/track/5wGLQvq6JoxYZX7V3ymPS5
# Song 5wGLQvq6JoxYZX7V3ymPS5 done, [430]
# https://open.spotify.com/track/3oiMJQAWVaxSubJ7b2VUtX
# Song 3oiMJQAWVaxSubJ7b2VUtX done, [431]
# https://open.spotify.com/track/7pNC5ZIKtwUK0ReSpM3P9f
# Song 7pNC5ZIKtwUK0ReSpM3P9f done, [432]
# https://open.spotify.com/track/6g6A7qNhTfUgOSH7ROOxTD
# Song 6g6A7qNhTfUgOSH7ROOxTD done, [433]
# https://open.spotify.com/track/2sLwPnIP3CUVmIuHranJZU
# Song 2sLwPnIP3CUVmIuHranJZU done, [434]
# https://open.spotify.com/track/5KONnBIQ9LqCxyeSPin26k
# Song 5KONnBIQ9LqCxyeSPin26k done, [435]
# https://open.spotify.com/track/0Dc7J9VPV4eOInoxUiZrsL
# Song 0Dc7J9VPV4eOInoxUiZrsL done, [436]
# https://open.spotify.com/track/0puf9yIluy9W0vpMEUoAnN
# Song 0puf9yIluy9W0vpMEUoAnN done, [437]
# https://open.spotify.com/track/3U4isOIWM3VvDubwSI3y7a
# Song 3U4isOIWM3VvDubwSI3y7a done, [438]
# https://open.spotify.com/track/3nB82yGjtbQFSU0JLAwLRH
# Song 3nB82yGjtbQFSU0JLAwLRH done, [439]
# https://open.spotify.com/track/4jbmgIyjGoXjY01XxatOx6
# Song 4jbmgIyjGoXjY01XxatOx6 done, [440]
# https://open.spotify.com/track/4q6dqyGM25sKFU8nYAGRe4
# Song 4q6dqyGM25sKFU8nYAGRe4 done, [441]
# https://open.spotify.com/track/51tUT1gHE30GQPhn1agudM
# Song 51tUT1gHE30GQPhn1agudM done, [442]
# https://open.spotify.com/track/4G92yYrUs0cvY7G41YRI0z
# Song 4G92yYrUs0cvY7G41YRI0z done, [443]
# https://open.spotify.com/track/5fnA9mkIfScSqHIpeDyvck
# Song 5fnA9mkIfScSqHIpeDyvck done, [444]
# https://open.spotify.com/track/3G6hD9B2ZHOsgf4WfNu7X1
# Song 3G6hD9B2ZHOsgf4WfNu7X1 done, [445]
# https://open.spotify.com/track/6RtPijgfPKROxEzTHNRiDp
# Song 6RtPijgfPKROxEzTHNRiDp done, [446]
# https://open.spotify.com/track/4gbVRS8gloEluzf0GzDOFc
# Song 4gbVRS8gloEluzf0GzDOFc done, [447]
# https://open.spotify.com/track/2bL2gyO6kBdLkNSkxXNh6x
# Song 2bL2gyO6kBdLkNSkxXNh6x done, [448]
# https://open.spotify.com/track/2iuZJX9X9P0GKaE93xcPjk
# Song 2iuZJX9X9P0GKaE93xcPjk done, [449]
# Song 0zO8ctW0UiuOefR87OeJOZ done, [473]
# https://open.spotify.com/track/5SsR3wtCOafDmZgvIdRhSm
# Song 5SsR3wtCOafDmZgvIdRhSm done, [474]
# https://open.spotify.com/track/0qt5f5EL92o8Snzopsv0en
# Song 0qt5f5EL92o8Snzopsv0en done, [475]
# https://open.spotify.com/track/2s1sdSqGcKxpPr5lCl7jAV
# Song 2s1sdSqGcKxpPr5lCl7jAV done, [476]
# https://open.spotify.com/track/5S9lfZu1YF8xKkgSsqL2Bd
# Song 5S9lfZu1YF8xKkgSsqL2Bd done, [477]
# https://open.spotify.com/track/6OazQAZl4yCHQmPfKP7B9V
# Song 6OazQAZl4yCHQmPfKP7B9V done, [478]
# https://open.spotify.com/track/4lIxdJw6W3Fg4vUIYCB0S5
# Song 4lIxdJw6W3Fg4vUIYCB0S5 done, [479]
# https://open.spotify.com/track/273dCMFseLcVsoSWx59IoE
# Song 273dCMFseLcVsoSWx59IoE done, [480]
# https://open.spotify.com/track/5xTtaWoae3wi06K5WfVUUH
# Song 5xTtaWoae3wi06K5WfVUUH done, [481]
# https://open.spotify.com/track/1HOlb9rdNOmy9b1Fakicjo
# Song 1HOlb9rdNOmy9b1Fakicjo done, [482]
# https://open.spotify.com/track/37sINbJZcFdHFAsVNsPq1i
# Song 37sINbJZcFdHFAsVNsPq1i done, [483]
# https://open.spotify.com/track/7m3povhdMDLZwuEKak0l0n
# Song 7m3povhdMDLZwuEKak0l0n done, [484]
# https://open.spotify.com/track/5L2l7mI8J1USMzhsmdjat9
# Song 5L2l7mI8J1USMzhsmdjat9 done, [485]
# https://open.spotify.com/track/3jVtllWS5CFFWLQng8sKsr
# Song 3jVtllWS5CFFWLQng8sKsr done, [486]
# https://open.spotify.com/track/14OxJlLdcHNpgsm4DRwDOB
# Song 14OxJlLdcHNpgsm4DRwDOB done, [487]
# https://open.spotify.com/track/2tpfxAXiI52znho4WE3XFA
# Song 2tpfxAXiI52znho4WE3XFA done, [488]
# https://open.spotify.com/track/5LIleJbUUgtvYnBW9wfY1W
# Song 5LIleJbUUgtvYnBW9wfY1W done, [489]
# https://open.spotify.com/track/2uXlHCUbq9OMUwx3hrk06o
# Song 2uXlHCUbq9OMUwx3hrk06o done, [490]
# https://open.spotify.com/track/2QtJA4gbwe1AcanB2p21aP
# Song 2QtJA4gbwe1AcanB2p21aP done, [491]
# https://open.spotify.com/track/2GQEM9JuHu30sGFvRYeCxz
# Song 2GQEM9JuHu30sGFvRYeCxz done, [492]
# https://open.spotify.com/track/44aN5xKL3kGHvQ5bXVk6B8
# Song 44aN5xKL3kGHvQ5bXVk6B8 done, [493]
# https://open.spotify.com/track/5zUQZjVB6bfewBXWqsP9PY
# Song 5zUQZjVB6bfewBXWqsP9PY done, [494]
# https://open.spotify.com/track/4Tt6GiWS2V9sQjZjS2xjp2
# Song 4Tt6GiWS2V9sQjZjS2xjp2 done, [495]
# https://open.spotify.com/track/5J4ZkQpzMUFojo1CtAZYpn
# Song 5J4ZkQpzMUFojo1CtAZYpn done, [496]
# https://open.spotify.com/track/0ct6r3EGTcMLPtrXHDvVjc
# Song 0ct6r3EGTcMLPtrXHDvVjc done, [497]
# https://open.spotify.com/track/2P4OICZRVAQcYAV2JReRfj
# Song 2P4OICZRVAQcYAV2JReRfj done, [498]
# https://open.spotify.com/track/7FYH5AW3bVfZHJIQpq3UOA
# Song 7FYH5AW3bVfZHJIQpq3UOA done, [499]
# ------------------------------
# # of Titles: 100
# # of Artists: 100
# # of Streams: 100

# %%
chunk4 = pd.DataFrame({'title': titles4, 'artist': artists4, 'streams': streams4})
chunk4.to_csv('chunk4_raw.csv', encoding = 'UTF-8', index=False)

# %%
browser = webdriver.Chrome()

titles5 = []
artists5 = [] 
streams5 = []


for i in range(500,600):
    track_id = apisongs.iloc[i]['track_id']
    url = f"https://open.spotify.com/track/{track_id}"
    print(url)

    browser.get(url)
    browser.maximize_window()

    total_wait_time = random.uniform(11, 14)  
    random_scroll(browser, total_wait_time)

    title_elements = browser.find_elements(By.CSS_SELECTOR, 'h1.encore-text.encore-text-headline-large[data-encore-id="text"]')
    for title in title_elements:
        titles5.append(title.text)

    artist_elements = browser.find_elements(By.CSS_SELECTOR, 'a[data-testid="creator-link"]')
    for artist_elem in artist_elements:
        artists5.append(artist_elem.text)  

    streams_elements = browser.find_elements(By.CSS_SELECTOR, 'span[data-testid="playcount"]')
    for streams_elem in streams_elements:
        streams5.append(streams_elem.text)  

    print(f"Song {track_id} done, {[i]}")

    time.sleep(random.randint(6,8))

browser.close()

print("-"* 30)
print(f"# of Titles: {len(titles5)}")  
print(f"# of Artists: {len(artists5)}") 
print(f"# of Streams: {len(streams5)}")
# Out:
# https://open.spotify.com/track/2GiJYvgVaD2HtM8GqD9EgQ
# Song 2GiJYvgVaD2HtM8GqD9EgQ done, [500]
# https://open.spotify.com/track/3pXF1nA74528Edde4of9CC
# Song 3pXF1nA74528Edde4of9CC done, [501]
# https://open.spotify.com/track/7MmG8p0F9N3C4AXdK6o6Eb
# Song 7MmG8p0F9N3C4AXdK6o6Eb done, [502]
# https://open.spotify.com/track/22mek4IiqubGD9ctzxc69s
# Song 22mek4IiqubGD9ctzxc69s done, [503]
# https://open.spotify.com/track/0k6DnZMLoEUH8NGD5zh2SE
# Song 0k6DnZMLoEUH8NGD5zh2SE done, [504]
# https://open.spotify.com/track/3uwnnTQcHM1rDqSfA4gQNz
# Song 3uwnnTQcHM1rDqSfA4gQNz done, [505]
# https://open.spotify.com/track/3DXXKDbbZKyAZfNb96ST3q
# Song 3DXXKDbbZKyAZfNb96ST3q done, [506]
# https://open.spotify.com/track/3MOECVkNshqHYTPt5DZcdN
# Song 3MOECVkNshqHYTPt5DZcdN done, [507]
# https://open.spotify.com/track/78EQ5LZGgviMU9k0zrqv1r
# Song 78EQ5LZGgviMU9k0zrqv1r done, [508]
# https://open.spotify.com/track/57kR5SniQIbsbVoIjjOUDa
# Song 57kR5SniQIbsbVoIjjOUDa done, [509]
# https://open.spotify.com/track/0wwPcA6wtMf6HUMpIRdeP7
# Song 0wwPcA6wtMf6HUMpIRdeP7 done, [510]
# https://open.spotify.com/track/27GmP9AWRs744SzKcpJsTZ
# Song 27GmP9AWRs744SzKcpJsTZ done, [511]
# https://open.spotify.com/track/34gCuhDGsG4bRPIf9bb02f
# Song 34gCuhDGsG4bRPIf9bb02f done, [512]
# https://open.spotify.com/track/3zHq9ouUJQFQRf3cm1rRLu
# Song 3zHq9ouUJQFQRf3cm1rRLu done, [513]
# https://open.spotify.com/track/5a7NdkF09AfD0H607eiOkX
# Song 5a7NdkF09AfD0H607eiOkX done, [514]
# https://open.spotify.com/track/04aAxqtGp5pv12UXAg4pkq
# Song 04aAxqtGp5pv12UXAg4pkq done, [515]
# https://open.spotify.com/track/5NQbUaeTEOGdD6hHcre0dZ
# https://open.spotify.com/track/32OlwWuMpZ6b0aN2RZOeMS
# Song 32OlwWuMpZ6b0aN2RZOeMS done, [540]
# https://open.spotify.com/track/0dbQ4h3cs8QE5fOPMYdDrX
# Song 0dbQ4h3cs8QE5fOPMYdDrX done, [541]
# https://open.spotify.com/track/0hy1SOTEn9ifXTzOwnCwEr
# Song 0hy1SOTEn9ifXTzOwnCwEr done, [542]
# https://open.spotify.com/track/5CN13QjYdc9s4aFg2wxwnE
# Song 5CN13QjYdc9s4aFg2wxwnE done, [543]
# https://open.spotify.com/track/7ioiB40H9xKs04QtIso2I3
# Song 7ioiB40H9xKs04QtIso2I3 done, [544]
# https://open.spotify.com/track/3icbmPGKTsKAa0IinkizCM
# Song 3icbmPGKTsKAa0IinkizCM done, [545]
# https://open.spotify.com/track/2kJqNHHGOzLNahukdvlDWN
# Song 2kJqNHHGOzLNahukdvlDWN done, [546]
# https://open.spotify.com/track/0fgZUSa7D7aVvv3GfO0A1n
# Song 0fgZUSa7D7aVvv3GfO0A1n done, [547]
# https://open.spotify.com/track/2K87XMYnUMqLcX3zvtAF4G
# Song 2K87XMYnUMqLcX3zvtAF4G done, [548]
# https://open.spotify.com/track/3NLnwwAQbbFKcEcV8hDItk
# Song 3NLnwwAQbbFKcEcV8hDItk done, [549]
# https://open.spotify.com/track/0hNduWmlWmEmuwEFcYvRu1
# Song 0hNduWmlWmEmuwEFcYvRu1 done, [550]
# https://open.spotify.com/track/412luShbmlgqqgYFStIB1s
# Song 412luShbmlgqqgYFStIB1s done, [551]
# https://open.spotify.com/track/2bJvI42r8EF3wxjOuDav4r
# Song 2bJvI42r8EF3wxjOuDav4r done, [552]
# https://open.spotify.com/track/4scpF6J5uMBvoh6sFB7EL1
# Song 4scpF6J5uMBvoh6sFB7EL1 done, [553]
# https://open.spotify.com/track/4T0ScSPdQKmGvruK7pavNP
# Song 4T0ScSPdQKmGvruK7pavNP done, [554]
# https://open.spotify.com/track/78TTtXnFQPzwqlbtbwqN0y
# Song 78TTtXnFQPzwqlbtbwqN0y done, [555]
# https://open.spotify.com/track/0NTMtAO2BV4tnGvw9EgBVq
# Song 0NTMtAO2BV4tnGvw9EgBVq done, [556]
# https://open.spotify.com/track/5uDASfU19gDxSjW8cnCaBp
# Song 5uDASfU19gDxSjW8cnCaBp done, [557]
# https://open.spotify.com/track/5tf1VVWniHgryyumXyJM7w
# Song 5tf1VVWniHgryyumXyJM7w done, [558]
# https://open.spotify.com/track/38ismoqQYn75ruDSQ2Jtx8
# Song 38ismoqQYn75ruDSQ2Jtx8 done, [559]
# https://open.spotify.com/track/2TeLIzFBe3hxkPR5FIQZut
# Song 2TeLIzFBe3hxkPR5FIQZut done, [560]
# https://open.spotify.com/track/2CpH1L4CUR47RARB3PgY1l
# Song 2CpH1L4CUR47RARB3PgY1l done, [561]
# https://open.spotify.com/track/1BZG99C7Co1r6QUC3zaS59
# Song 1BZG99C7Co1r6QUC3zaS59 done, [562]
# https://open.spotify.com/track/1LoriJC05IrHIDwj3q0KC1
# Song 1LoriJC05IrHIDwj3q0KC1 done, [563]
# https://open.spotify.com/track/578Eooad7oUyn4stovZiPg
# Song 578Eooad7oUyn4stovZiPg done, [564]
# https://open.spotify.com/track/0qt5f5EL92o8Snzopsv0en
# Song 0qt5f5EL92o8Snzopsv0en done, [565]
# https://open.spotify.com/track/5s7xgzXtmY4gMjeSlgisjy
# Song 5s7xgzXtmY4gMjeSlgisjy done, [566]
# https://open.spotify.com/track/6TaqooOXAEcijL6G1AWS2K
# Song 6TaqooOXAEcijL6G1AWS2K done, [567]
# https://open.spotify.com/track/6K4t31amVTZDgR3sKmwUJJ
# Song 6K4t31amVTZDgR3sKmwUJJ done, [568]
# https://open.spotify.com/track/1p80LdxRV74UKvL8gnD7ky
# Song 1p80LdxRV74UKvL8gnD7ky done, [569]
# https://open.spotify.com/track/59HjlYCeBsxdI0fcm3zglw
# Song 59HjlYCeBsxdI0fcm3zglw done, [570]
# https://open.spotify.com/track/6xsEAm6w9oMQYYg3jkEkMT
# Song 6xsEAm6w9oMQYYg3jkEkMT done, [571]
# https://open.spotify.com/track/4lIxdJw6W3Fg4vUIYCB0S5
# Song 4lIxdJw6W3Fg4vUIYCB0S5 done, [572]
# https://open.spotify.com/track/47QDvqfpUTIGckdCacLd8P
# Song 47QDvqfpUTIGckdCacLd8P done, [573]
# https://open.spotify.com/track/7fBv7CLKzipRk6EC6TWHOB
# Song 7fBv7CLKzipRk6EC6TWHOB done, [574]
# https://open.spotify.com/track/22VdIZQfgXJea34mQxlt81
# Song 22VdIZQfgXJea34mQxlt81 done, [575]
# https://open.spotify.com/track/2PIvq1pGrUjY007X5y1UpM
# Song 2PIvq1pGrUjY007X5y1UpM done, [576]
# https://open.spotify.com/track/25KybV9BOUlvcnv7nN3Pyo
# Song 25KybV9BOUlvcnv7nN3Pyo done, [577]
# https://open.spotify.com/track/5kNe7PE09d6Kvw5pAsx23n
# Song 5kNe7PE09d6Kvw5pAsx23n done, [578]
# https://open.spotify.com/track/2tpfxAXiI52znho4WE3XFA
# Song 2tpfxAXiI52znho4WE3XFA done, [579]
# https://open.spotify.com/track/1wHZx0LgzFHyeIZkUydNXq
# Song 1wHZx0LgzFHyeIZkUydNXq done, [580]
# https://open.spotify.com/track/4NYwy0R3NdvORX2B6OZXBT
# Song 4NYwy0R3NdvORX2B6OZXBT done, [581]
# https://open.spotify.com/track/5LIleJbUUgtvYnBW9wfY1W
# Song 5LIleJbUUgtvYnBW9wfY1W done, [582]
# https://open.spotify.com/track/1cOyWWUr3oXJIxY0AjJEx9
# Song 1cOyWWUr3oXJIxY0AjJEx9 done, [583]
# https://open.spotify.com/track/3CRDbSIZ4r5MsZ0YwxuEkn
# Song 3CRDbSIZ4r5MsZ0YwxuEkn done, [584]
# https://open.spotify.com/track/7aXuop4Qambx5Oi3ynsKQr
# Song 7aXuop4Qambx5Oi3ynsKQr done, [585]
# https://open.spotify.com/track/4kbj5MwxO1bq9wjT5g9HaA
# Song 4kbj5MwxO1bq9wjT5g9HaA done, [586]
# https://open.spotify.com/track/2JzZzZUQj3Qff7wapcbKjc
# Song 2JzZzZUQj3Qff7wapcbKjc done, [587]
# https://open.spotify.com/track/0fYVliAYKHuPmECRs1pbRf
# Song 0fYVliAYKHuPmECRs1pbRf done, [588]
# https://open.spotify.com/track/7lGKEWMXVWWTt3X71Bv44I
# Song 7lGKEWMXVWWTt3X71Bv44I done, [589]
# https://open.spotify.com/track/5Z3zRrMIJk7CVpfcLsM9wD
# Song 5Z3zRrMIJk7CVpfcLsM9wD done, [590]
# https://open.spotify.com/track/1JDIArrcepzWDTAWXdGYmP
# Song 1JDIArrcepzWDTAWXdGYmP done, [591]
# https://open.spotify.com/track/7GgWAITsYJaRM3r50rfh5w
# Song 7GgWAITsYJaRM3r50rfh5w done, [592]
# https://open.spotify.com/track/0t7fVeEJxO2Xi4H2K5Svc9
# Song 0t7fVeEJxO2Xi4H2K5Svc9 done, [593]
# https://open.spotify.com/track/62PaSfnXSMyLshYJrlTuL3
# Song 62PaSfnXSMyLshYJrlTuL3 done, [594]
# https://open.spotify.com/track/5zUQZjVB6bfewBXWqsP9PY
# Song 5zUQZjVB6bfewBXWqsP9PY done, [595]
# https://open.spotify.com/track/0OwX5aROoW1Iip8FV51Efg
# Song 0OwX5aROoW1Iip8FV51Efg done, [596]
# https://open.spotify.com/track/63y6xWR4gXz7bnUGOk8iI6
# Song 63y6xWR4gXz7bnUGOk8iI6 done, [597]
# https://open.spotify.com/track/43bCmCI0nSgcT7QdMXY6LV
# Song 43bCmCI0nSgcT7QdMXY6LV done, [598]
# https://open.spotify.com/track/6RUhbFEhrvGISaQ8u2j2JN
# Song 6RUhbFEhrvGISaQ8u2j2JN done, [599]
# ------------------------------
# # of Titles: 100
# # of Artists: 100
# # of Streams: 100

# %%
chunk5 = pd.DataFrame({'title': titles5, 'artist': artists5, 'streams': streams5})
chunk5.to_csv('chunk5_raw.csv', encoding = 'UTF-8', index=False)

# %%
browser = webdriver.Chrome()

titles6 = []
artists6 = []  
streams6 = []


for i in range(600,700):
    track_id = apisongs.iloc[i]['track_id']
    url = f"https://open.spotify.com/track/{track_id}"
    print(url)

    browser.get(url)
    browser.maximize_window()

    total_wait_time = random.uniform(11, 14)  
    random_scroll(browser, total_wait_time)

    title_elements = browser.find_elements(By.CSS_SELECTOR, 'h1.encore-text.encore-text-headline-large[data-encore-id="text"]')
    for title in title_elements:
        titles6.append(title.text)

    artist_elements = browser.find_elements(By.CSS_SELECTOR, 'a[data-testid="creator-link"]')
    for artist_elem in artist_elements:
        artists6.append(artist_elem.text) 

    streams_elements = browser.find_elements(By.CSS_SELECTOR, 'span[data-testid="playcount"]')
    for streams_elem in streams_elements:
        streams6.append(streams_elem.text)  

    print(f"Song {track_id} done, {[i]}")

    time.sleep(random.randint(6,8))

browser.close()

print("-"* 30)
print(f"# of Titles: {len(titles6)}")  
print(f"# of Artists: {len(artists6)}")  
print(f"# of Streams: {len(streams6)}")
# Out:
# https://open.spotify.com/track/46u5B2WN4wryYLZuMAOmI4
# Song 46u5B2WN4wryYLZuMAOmI4 done, [600]
# https://open.spotify.com/track/1oxOiOjsi7plNOZEhoPLPj
# Song 1oxOiOjsi7plNOZEhoPLPj done, [601]
# https://open.spotify.com/track/0lnIJmgcUpEpe4AZACjayW
# Song 0lnIJmgcUpEpe4AZACjayW done, [602]
# https://open.spotify.com/track/3pXF1nA74528Edde4of9CC
# Song 3pXF1nA74528Edde4of9CC done, [603]
# https://open.spotify.com/track/43PuMrRfbyyuz4QpZ3oAwN
# Song 43PuMrRfbyyuz4QpZ3oAwN done, [604]
# https://open.spotify.com/track/2BOqDYLOJBiMOXShCV1neZ
# Song 2BOqDYLOJBiMOXShCV1neZ done, [605]
# https://open.spotify.com/track/1vvNmPOiUuyCbgWmtc6yf

# ------------------------------
# # of Titles: 100
# # of Artists: 100
# # of Streams: 100

# %%
chunk6 = pd.DataFrame({'title': titles6, 'artist': artists6, 'streams': streams6})
chunk6.to_csv('chunk6_raw.csv', encoding = 'UTF-8', index=False)

# %%
browser = webdriver.Chrome()

titles7 = []
artists7 = []  
streams7 = []


for i in range(700,800):
    track_id = apisongs.iloc[i]['track_id']
    url = f"https://open.spotify.com/track/{track_id}"
    print(url)

    browser.get(url)
    browser.maximize_window()

    total_wait_time = random.uniform(11, 14)  
    random_scroll(browser, total_wait_time)

    title_elements = browser.find_elements(By.CSS_SELECTOR, 'h1.encore-text.encore-text-headline-large[data-encore-id="text"]')
    for title in title_elements:
        titles7.append(title.text)

    artist_elements = browser.find_elements(By.CSS_SELECTOR, 'a[data-testid="creator-link"]')
    for artist_elem in artist_elements:
        artists7.append(artist_elem.text) 

    streams_elements = browser.find_elements(By.CSS_SELECTOR, 'span[data-testid="playcount"]')
    for streams_elem in streams_elements:
        streams7.append(streams_elem.text)  

    print(f"Song {track_id} done, {[i]}")

    time.sleep(random.randint(6,8))

browser.close()

print("-"* 30)
print(f"# of Titles: {len(titles7)}")  
print(f"# of Artists: {len(artists7)}")  
print(f"# of Streams: {len(streams7)}")
# Out:
# https://open.spotify.com/track/6X5OFBbrsHRsyO1zP7udgr
# Song 6X5OFBbrsHRsyO1zP7udgr done, [700]
# https://open.spotify.com/track/04sN26COy28wTXYj3dMoiZ
# Song 04sN26COy28wTXYj3dMoiZ done, [701]
# https://open.spotify.com/track/6Se3x9ANMLv0dCDsjGmEjh
# Song 6Se3x9ANMLv0dCDsjGmEjh done, [702]
# https://open.spotify.com/track/0KKkJNfGyhkQ5aFogxQAPU
# Song 0KKkJNfGyhkQ5aFogxQAPU done, [703]
# https://open.spotify.com/track/6b8Be6ljOzmkOmFslEb23P
# Song 6b8Be6ljOzmkOmFslEb23P done, [704]
# https://open.spotify.com/track/5bcTCxgc7xVfSaMV3RuVke
# Song 5bcTCxgc7xVfSaMV3RuVke done, [705]
# https://open.spotify.com/track/7tr2za8SQg2CI8EDgrdtNl
# Song 7tr2za8SQg2CI8EDgrdtNl done, [706]
# https://open.spotify.com/track/1rfofaqEpACxVEHIZBJe6W
# Song 1rfofaqEpACxVEHIZBJe6W done, [707]
# https://open.spotify.com/track/6KBYefIoo7KydImq1uUQlL
# Song 6KBYefIoo7KydImq1uUQlL done, [708]
# https://open.spotify.com/track/5lNuqFVMca4vPupY10cH0J
# Song 5lNuqFVMca4vPupY10cH0J done, [709]
# https://open.spotify.com/track/3vQ4T78TTMOjQXGfXVKQJo
# Song 3vQ4T78TTMOjQXGfXVKQJo done, [710]
# https://open.spotify.com/track/5knuzwU65gJK7IF5yJsuaW
# Song 5knuzwU65gJK7IF5yJsuaW done, [711]
# https://open.spotify.com/track/0yvPEnB032fojLfVluFjUv
# Song 0yvPEnB032fojLfVluFjUv done, [712]
# https://open.spotify.com/track/1jYiIOC5d6soxkJP81fxq2
# Song 1jYiIOC5d6soxkJP81fxq2 done, [713]
# https://open.spotify.com/track/45XhKYRRkyeqoW3teSOkCM
# Song 45XhKYRRkyeqoW3teSOkCM done, [714]
# https://open.spotify.com/track/5mCPDVBb16L4XQwDdbRUpz
# Song 5mCPDVBb16L4XQwDdbRUpz done, [715]
# https://open.spotify.com/track/343YBumqHu19cGoGARUTsd
# Song 343YBumqHu19cGoGARUTsd done, [716]
# https://open.spotify.com/track/0tgVpDi06FyKpA1z0VMD4v
# Song 0tgVpDi06FyKpA1z0VMD4v done, [717]
# https://open.spotify.com/track/7qiZfU4dY1lWllzX7mPBI3
# Song 7qiZfU4dY1lWllzX7mPBI3 done, [718]
# https://open.spotify.com/track/4BdGO1CaObRD4La9l5Zanz
# Song 4BdGO1CaObRD4La9l5Zanz done, [719]
# https://open.spotify.com/track/3B54sVLJ402zGa6Xm4YGNe
# Song 3B54sVLJ402zGa6Xm4YGNe done, [720]
# https://open.spotify.com/track/0VgkVdmE4gld66l8iyGjgx
# Song 0VgkVdmE4gld66l8iyGjgx done, [721]
# https://open.spotify.com/track/5k38wzpLb15YgncyWdTZE4
# Song 5k38wzpLb15YgncyWdTZE4 done, [722]
# https://open.spotify.com/track/2DQ1ITjI0YoLFzuADN1ZBW
# Song 2DQ1ITjI0YoLFzuADN1ZBW done, [723]
# https://open.spotify.com/track/10GJQkjRJcZhGTLagFOC62
# Song 10GJQkjRJcZhGTLagFOC62 done, [724]
# https://open.spotify.com/track/126oeltvIg79HHP4yAi4rq
# Song 126oeltvIg79HHP4yAi4rq done, [725]
# https://open.spotify.com/track/0LOuhyBqfn1diyqKIsCbOJ
# Song 0LOuhyBqfn1diyqKIsCbOJ done, [726]
# https://open.spotify.com/track/0pqnGHJpmpxLKifKRmU6WP
# Song 0pqnGHJpmpxLKifKRmU6WP done, [727]
# https://open.spotify.com/track/1zB4vmk8tFRmM9UULNzbLB
# Song 1zB4vmk8tFRmM9UULNzbLB done, [728]
# https://open.spotify.com/track/6Qn5zhYkTa37e91HC1D7lb
# Song 6Qn5zhYkTa37e91HC1D7lb done, [729]
# https://open.spotify.com/track/7KXjTSCq5nL1LoYtL7XAwS
# Song 7KXjTSCq5nL1LoYtL7XAwS done, [730]
# https://open.spotify.com/track/6PGoSes0D9eUDeeAafB2As
# Song 6PGoSes0D9eUDeeAafB2As done, [731]
# https://open.spotify.com/track/6HZILIRieu8S0iqY8kIKhj
# Song 6HZILIRieu8S0iqY8kIKhj done, [732]
# https://open.spotify.com/track/1EaKU4dMbesXXd3BrLCtYG
# Song 1EaKU4dMbesXXd3BrLCtYG done, [733]
# https://open.spotify.com/track/5Z3GHaZ6ec9bsiI5BenrbY
# Song 5Z3GHaZ6ec9bsiI5BenrbY done, [734]
# https://open.spotify.com/track/152lZdxL1OR0ZMW6KquMif
# Song 152lZdxL1OR0ZMW6KquMif done, [735]
# https://open.spotify.com/track/4Q3N4Ct4zCuIHuZ65E3BD4
# Song 4Q3N4Ct4zCuIHuZ65E3BD4 done, [736]
# https://open.spotify.com/track/2EEeOnHehOozLq4aS0n6SL
# Song 2EEeOnHehOozLq4aS0n6SL done, [737]
# https://open.spotify.com/track/0mt02gJ425Xjm7c3jYkOBn
# Song 0mt02gJ425Xjm7c3jYkOBn done, [738]
# https://open.spotify.com/track/29JrmE89KgRyCxBIzq2Ocw
# Song 29JrmE89KgRyCxBIzq2Ocw done, [739]
# https://open.spotify.com/track/3VZlCJimDGY0D7YEC7S351
# Song 3VZlCJimDGY0D7YEC7S351 done, [740]
# https://open.spotify.com/track/43ZyHQITOjhciSUUNPVRHc
# Song 43ZyHQITOjhciSUUNPVRHc done, [741]
# https://open.spotify.com/track/7GX5flRQZVHRAGd6B4TmDO
# Song 7GX5flRQZVHRAGd6B4TmDO done, [742]
# https://open.spotify.com/track/3TdXFHsGYGYEYP6Kg3he9W
# Song 3TdXFHsGYGYEYP6Kg3he9W done, [743]
# https://open.spotify.com/track/5tz69p7tJuGPeMGwNTxYuV
# Song 5tz69p7tJuGPeMGwNTxYuV done, [744]
# https://open.spotify.com/track/6Kkt27YmFyIFrcX3QXFi2o
# Song 6Kkt27YmFyIFrcX3QXFi2o done, [745]
# https://open.spotify.com/track/2HBtd9MYDd2xDVu8Zc6pwt
# Song 2HBtd9MYDd2xDVu8Zc6pwt done, [793]
# https://open.spotify.com/track/5OCJzvD7sykQEKHH7qAC3C
# Song 5OCJzvD7sykQEKHH7qAC3C done, [794]
# https://open.spotify.com/track/2qT1uLXPVPzGgFOx4jtEuo
# Song 2qT1uLXPVPzGgFOx4jtEuo done, [795]
# https://open.spotify.com/track/4PzsYXrHh4r2BxtpNjtvoF
# Song 4PzsYXrHh4r2BxtpNjtvoF done, [796]
# https://open.spotify.com/track/1HagMz5nWk1HmevNCBOxF3
# Song 1HagMz5nWk1HmevNCBOxF3 done, [797]
# https://open.spotify.com/track/7uzmGiiJyRfuViKKK3lVmR
# Song 7uzmGiiJyRfuViKKK3lVmR done, [798]
# https://open.spotify.com/track/7FGq80cy8juXBCD2nrqdWU
# Song 7FGq80cy8juXBCD2nrqdWU done, [799]
# ------------------------------
# # of Titles: 100
# # of Artists: 100
# # of Streams: 100

# %%
chunk7 = pd.DataFrame({'title': titles7, 'artist': artists7, 'streams': streams7})
chunk7.to_csv('chunk7_raw.csv', encoding = 'UTF-8', index=False)

# %%
browser = webdriver.Chrome()

titles8 = []
artists8 = []  
streams8 = []


for i in range(800,900):
    track_id = apisongs.iloc[i]['track_id']
    url = f"https://open.spotify.com/track/{track_id}"
    print(url)

    browser.get(url)
    browser.maximize_window()

    total_wait_time = random.uniform(15, 20)  
    random_scroll(browser, total_wait_time)

    title_elements = browser.find_elements(By.CSS_SELECTOR, 'h1.encore-text.encore-text-headline-large[data-encore-id="text"]')
    for title in title_elements:
        titles8.append(title.text)

    artist_elements = browser.find_elements(By.CSS_SELECTOR, 'a[data-testid="creator-link"]')
    for artist_elem in artist_elements:
        artists8.append(artist_elem.text)  

    streams_elements = browser.find_elements(By.CSS_SELECTOR, 'span[data-testid="playcount"]')
    for streams_elem in streams_elements:
        streams8.append(streams_elem.text)  

    print(f"Song {track_id} done, {[i]}")

    time.sleep(random.randint(6,8))

browser.close()

print("-"* 30)
print(f"# of Titles: {len(titles8)}")  
print(f"# of Artists: {len(artists8)}")  
print(f"# of Streams: {len(streams8)}")
# Out:
# https://open.spotify.com/track/0u2P5u6lvoDfwTYjAADbn4
# Song 0u2P5u6lvoDfwTYjAADbn4 done, [800]
# https://open.spotify.com/track/6HJ34Zyw6bg8yGm28AxLXf
# Song 6HJ34Zyw6bg8yGm28AxLXf done, [801]
# https://open.spotify.com/track/3Vo4wInECJQuz9BIBMOu8i
# Song 3Vo4wInECJQuz9BIBMOu8i done, [802]
# https://open.spotify.com/track/7ef4DlsgrMEH11cDZd32M6
# Song 7ef4DlsgrMEH11cDZd32M6 done, [803]
# https://open.spotify.com/track/4eWQlBRaTjPPUlzacqEeoQ
# Song 4eWQlBRaTjPPUlzacqEeoQ done, [804]
# https://open.spotify.com/track/58q2HKrzhC3ozto2nDdN4z
# Song 58q2HKrzhC3ozto2nDdN4z done, [805]
# https://open.spotify.com/track/6KBYefIoo7KydImq1uUQlL
# Song 6KBYefIoo7KydImq1uUQlL done, [806]
# https://open.spotify.com/track/2Yl4OmDby9iitgNWZPwxkd
# Song 2Yl4OmDby9iitgNWZPwxkd done, [807]
# https://open.spotify.com/track/7HdZY9UJTylIiNcSDFyUDc
# Song 7HdZY9UJTylIiNcSDFyUDc done, [808]
# https://open.spotify.com/track/6wmAHw1szh5RCKSRjiXhPe
# Song 6wmAHw1szh5RCKSRjiXhPe done, [809]
# https://open.spotify.com/track/1lsBTdE6MGsKeZCD6llNu7
# Song 1lsBTdE6MGsKeZCD6llNu7 done, [810]
# https://open.spotify.com/track/6qNALlmZa1ESnCxJmXE1K9
# Song 6qNALlmZa1ESnCxJmXE1K9 done, [811]
# https://open.spotify.com/track/0b9oOr2ZgvyQu88wzixux9
# Song 0b9oOr2ZgvyQu88wzixux9 done, [812]
# https://open.spotify.com/track/42fw0rxRO2xbesF6mJfd4Y
# Song 2FY7b99s15jUprqC0M5NCT done, [836]
# https://open.spotify.com/track/5gW5dSy3vXJxgzma4rQuzH
# Song 5gW5dSy3vXJxgzma4rQuzH done, [837]
# https://open.spotify.com/track/2TXtN9MoV308Y0z1HvyTfV
# Song 2TXtN9MoV308Y0z1HvyTfV done, [838]
# https://open.spotify.com/track/51rXHuKN8Loc4sUlKPODgH
# Song 51rXHuKN8Loc4sUlKPODgH done, [839]
# https://open.spotify.com/track/5ZSl6gDoV6bPPxzmLeneV9
# Song 5ZSl6gDoV6bPPxzmLeneV9 done, [840]
# https://open.spotify.com/track/285pBltuF7vW8TeWk8hdRR
# Song 285pBltuF7vW8TeWk8hdRR done, [841]
# https://open.spotify.com/track/6PGoSes0D9eUDeeAafB2As
# Song 6PGoSes0D9eUDeeAafB2As done, [842]
# https://open.spotify.com/track/3GCdLUSnKSMJhs4Tj6CV3s
# Song 3GCdLUSnKSMJhs4Tj6CV3s done, [843]
# https://open.spotify.com/track/45Egmo7icyopuzJN0oMEdk
# Song 45Egmo7icyopuzJN0oMEdk done, [844]
# https://open.spotify.com/track/0CZ8lquoTX2Dkg7Ak2inwA
# Song 0CZ8lquoTX2Dkg7Ak2inwA done, [845]
# https://open.spotify.com/track/4MagTPnkPiDuIa4P8GtW1b
# Song 4MagTPnkPiDuIa4P8GtW1b done, [846]
# https://open.spotify.com/track/6vN77lE9LK6HP2DewaN6HZ
# Song 6vN77lE9LK6HP2DewaN6HZ done, [847]
# https://open.spotify.com/track/6dbSBQXCctYSVryynHXaZ4
# Song 6dbSBQXCctYSVryynHXaZ4 done, [848]
# https://open.spotify.com/track/4EAV2cKiqKP5UPZmY6dejk
# Song 4EAV2cKiqKP5UPZmY6dejk done, [849]
# https://open.spotify.com/track/21RzyxY3EFaxVy6K4RqaU9
# Song 21RzyxY3EFaxVy6K4RqaU9 done, [850]
# https://open.spotify.com/track/70eehEqNug7oAhozjhG21t
# Song 70eehEqNug7oAhozjhG21t done, [851]
# https://open.spotify.com/track/0OI7AFifLSoGzpb8bdBLLV
# Song 0OI7AFifLSoGzpb8bdBLLV done, [852]
# https://open.spotify.com/track/5cepAtqnEQ6yVG6088zMMu
# Song 5cepAtqnEQ6yVG6088zMMu done, [853]
# https://open.spotify.com/track/6AvfZXpbb6r35DfF7gHPRq
# Song 6AvfZXpbb6r35DfF7gHPRq done, [854]
# https://open.spotify.com/track/7BqHUALzNBTanL6OvsqmC1
# Song 7BqHUALzNBTanL6OvsqmC1 done, [855]
# https://open.spotify.com/track/7vGuf3Y35N4wmASOKLUVVU
# Song 7vGuf3Y35N4wmASOKLUVVU done, [856]
# https://open.spotify.com/track/08bNPGLD8AhKpnnERrAc6G
# Song 08bNPGLD8AhKpnnERrAc6G done, [857]
# https://open.spotify.com/track/6VrCmhRBFnuGKmtNfk4jDs
# Song 6VrCmhRBFnuGKmtNfk4jDs done, [858]
# https://open.spotify.com/track/6n4U3TlzUGhdSFbUUhTvLP
# Song 6n4U3TlzUGhdSFbUUhTvLP done, [859]
# https://open.spotify.com/track/4wFjTWCunQFKtukqrNijEt
# Song 4wFjTWCunQFKtukqrNijEt done, [860]
# https://open.spotify.com/track/2UVbBKQOdFAekPTRsnkzcf
# Song 2UVbBKQOdFAekPTRsnkzcf done, [861]
# https://open.spotify.com/track/15DwFznkBJir7AK9PyMyRR
# Song 15DwFznkBJir7AK9PyMyRR done, [862]
# https://open.spotify.com/track/52okn5MNA47tk87PeZJLEL
# Song 52okn5MNA47tk87PeZJLEL done, [863]
# https://open.spotify.com/track/3V8UKqhEK5zBkBb6d6ub8i
# Song 3V8UKqhEK5zBkBb6d6ub8i done, [864]
# https://open.spotify.com/track/7sO5G9EABYOXQKNPNiE9NR
# Song 7sO5G9EABYOXQKNPNiE9NR done, [865]
# https://open.spotify.com/track/48zFZh27QU5qsrBjn4C2FA
# Song 48zFZh27QU5qsrBjn4C2FA done, [866]
# https://open.spotify.com/track/1j6xOGusnyXq3l6IryKF3G
# Song 1j6xOGusnyXq3l6IryKF3G done, [867]
# https://open.spotify.com/track/0e7ipj03S05BNilyu5bRzt
# Song 0e7ipj03S05BNilyu5bRzt done, [868]
# https://open.spotify.com/track/7dt6x5M1jzdTEt8oCbisTK
# Song 7dt6x5M1jzdTEt8oCbisTK done, [869]
# https://open.spotify.com/track/3swc6WTsr7rl9DqQKQA55C
# Song 3swc6WTsr7rl9DqQKQA55C done, [870]
# https://open.spotify.com/track/1BuZAIO8WZpavWVbbq3Lci
# Song 1BuZAIO8WZpavWVbbq3Lci done, [871]
# https://open.spotify.com/track/1ZAyjvIk9YiD76yYy0TEG6
# Song 1ZAyjvIk9YiD76yYy0TEG6 done, [872]
# https://open.spotify.com/track/1xzBco0xcoJEDXktl7Jxrr
# Song 1xzBco0xcoJEDXktl7Jxrr done, [873]
# https://open.spotify.com/track/3CWuU5kIw8zsWJTcgreUwl
# Song 3CWuU5kIw8zsWJTcgreUwl done, [874]
# https://open.spotify.com/track/6NFyWDv5CjfwuzoCkw47Xf
# Song 6NFyWDv5CjfwuzoCkw47Xf done, [875]
# https://open.spotify.com/track/3TgMcrV32NUKjEG2ujn9eh
# Song 3TgMcrV32NUKjEG2ujn9eh done, [876]
# https://open.spotify.com/track/4NBTZtAt1F13VvlSKe6KTl
# Song 4NBTZtAt1F13VvlSKe6KTl done, [877]
# https://open.spotify.com/track/58kZ9spgxmlEznXGu6FPdQ
# Song 58kZ9spgxmlEznXGu6FPdQ done, [878]
# https://open.spotify.com/track/09mEdoA6zrmBPgTEN5qXmN
# Song 09mEdoA6zrmBPgTEN5qXmN done, [879]
# https://open.spotify.com/track/77UjLW8j5UAGAGVGhR5oUK
# Song 77UjLW8j5UAGAGVGhR5oUK done, [880]
# https://open.spotify.com/track/4kWO6O1BUXcZmaxitpVUwp
# Song 4kWO6O1BUXcZmaxitpVUwp done, [881]
# https://open.spotify.com/track/2xLMifQCjDGFmkHkpNLD9h
# Song 2xLMifQCjDGFmkHkpNLD9h done, [882]
# https://open.spotify.com/track/5IaHrVsrferBYDm0bDyABy
# Song 5IaHrVsrferBYDm0bDyABy done, [883]
# https://open.spotify.com/track/2RiBogNRfulkNf7fVbPOrJ
# Song 2RiBogNRfulkNf7fVbPOrJ done, [884]
# https://open.spotify.com/track/3ee8Jmje8o58CHK66QrVC2
# Song 3ee8Jmje8o58CHK66QrVC2 done, [885]
# https://open.spotify.com/track/0JP9xo3adEtGSdUEISiszL
# Song 0JP9xo3adEtGSdUEISiszL done, [886]
# https://open.spotify.com/track/7AFASza1mXqntmGtbxXprO
# Song 7AFASza1mXqntmGtbxXprO done, [887]
# https://open.spotify.com/track/01k24g94i1JvkFLQmVEdCd
# Song 01k24g94i1JvkFLQmVEdCd done, [888]
# https://open.spotify.com/track/0ZNrc4kNeQYD9koZ3KvCsy
# Song 0ZNrc4kNeQYD9koZ3KvCsy done, [889]
# https://open.spotify.com/track/09IStsImFySgyp0pIQdqAc
# Song 09IStsImFySgyp0pIQdqAc done, [890]
# https://open.spotify.com/track/2t8yVaLvJ0RenpXUIAC52d
# Song 2t8yVaLvJ0RenpXUIAC52d done, [891]
# https://open.spotify.com/track/2bjUEg4jBtKBlPdNrTAppI
# Song 2bjUEg4jBtKBlPdNrTAppI done, [892]
# https://open.spotify.com/track/1wJRveJZLSb1rjhnUHQiv6
# Song 1wJRveJZLSb1rjhnUHQiv6 done, [893]
# https://open.spotify.com/track/3Ol2xnObFdKV9pmRD2t9x8
# Song 3Ol2xnObFdKV9pmRD2t9x8 done, [894]
# https://open.spotify.com/track/7AODNxFNPnKaz4hURLzw5l
# Song 7AODNxFNPnKaz4hURLzw5l done, [895]
# https://open.spotify.com/track/2ksOAxtIxY8yElEWw8RhgK
# Song 2ksOAxtIxY8yElEWw8RhgK done, [896]
# https://open.spotify.com/track/5W83ErFkO3aKAIS1WMi6u0
# Song 5W83ErFkO3aKAIS1WMi6u0 done, [897]
# https://open.spotify.com/track/6ocbgoVGwYJhOv1GgI9NsF
# Song 6ocbgoVGwYJhOv1GgI9NsF done, [898]
# https://open.spotify.com/track/3e9HZxeyfWwjeyPAMmWSSQ
# Song 3e9HZxeyfWwjeyPAMmWSSQ done, [899]
# ------------------------------
# # of Titles: 100
# # of Artists: 100
# # of Streams: 100

# %%
chunk8 = pd.DataFrame({'title': titles8, 'artist': artists8, 'streams': streams8})
chunk8.to_csv('chunk8_raw.csv', encoding = 'UTF-8', index=False)

# %%
browser = webdriver.Chrome()

titles9 = []
artists9 = []  
streams9 = []

for i in range(900,990):
    track_id = apisongs.iloc[i]['track_id']
    url = f"https://open.spotify.com/track/{track_id}"
    print(url)

    browser.get(url)
    browser.maximize_window()

    total_wait_time = random.uniform(11,14)  
    random_scroll(browser, total_wait_time)

    title_elements = browser.find_elements(By.CSS_SELECTOR, 'h1.encore-text.encore-text-headline-large[data-encore-id="text"]')
    for title in title_elements:
        titles9.append(title.text)

    artist_elements = browser.find_elements(By.CSS_SELECTOR, 'a[data-testid="creator-link"]')
    for artist_elem in artist_elements:
        artists9.append(artist_elem.text) 

    streams_elements = browser.find_elements(By.CSS_SELECTOR, 'span[data-testid="playcount"]')
    for streams_elem in streams_elements:
        streams9.append(streams_elem.text)  

    print(f"Song {track_id} done, {[i]}")

    time.sleep(random.randint(6,8))

browser.close()

print("-"* 30)
print(f"# of Titles: {len(titles9)}") 
print(f"# of Artists: {len(artists9)}")  
print(f"# of Streams: {len(streams9)}")
# Out:
# https://open.spotify.com/track/4kV4N9D1iKVxx1KLvtTpjS
# Song 4kV4N9D1iKVxx1KLvtTpjS done, [900]
# https://open.spotify.com/track/0Ryd8975WihbObpp5cPW1t
# Song 0Ryd8975WihbObpp5cPW1t done, [901]
# https://open.spotify.com/track/56JyMaElW79S7TDWh1Zw1m
# Song 56JyMaElW79S7TDWh1Zw1m done, [902]
# https://open.spotify.com/track/2TH65lNHgvLxCKXM3apjxI
# Song 2TH65lNHgvLxCKXM3apjxI done, [903]
# https://open.spotify.com/track/3Ueq2zboxwAbsvHrOjdEqz
# Song 3Ueq2zboxwAbsvHrOjdEqz done, [904]
# https://open.spotify.com/track/0u2P5u6lvoDfwTYjAADbn4
# Song 0u2P5u6lvoDfwTYjAADbn4 done, [905]
# https://open.spotify.com/track/2Fxmhks0bxGSBdJ92vM42m
# Song 2Fxmhks0bxGSBdJ92vM42m done, [906]
# https://open.spotify.com/track/43zdsphuZLzwA9k4DJhU0I
# Song 43zdsphuZLzwA9k4DJhU0I done, [907]
# https://open.spotify.com/track/4SSnFejRGlZikf02HLewEF
# Song 4SSnFejRGlZikf02HLewEF done, [908]
# https://open.spotify.com/track/6hvczQ05jc1yGlp9zhb95V
# Song 6hvczQ05jc1yGlp9zhb95V done, [909]
# https://open.spotify.com/track/01tA4XmJ4fGQNwti6b2hPm
# Song 01tA4XmJ4fGQNwti6b2hPm done, [910]
# https://open.spotify.com/track/1rBjexQsgqXpsS2BrCxaDX
# Song 1rBjexQsgqXpsS2BrCxaDX done, [911]
# https://open.spotify.com/track/4a9tbd947vo9K8Vti9JwcI
# Song 4a9tbd947vo9K8Vti9JwcI done, [912]
# https://open.spotify.com/track/0PG9fbaaHFHfre2gUVo7AN
# Song 0PG9fbaaHFHfre2gUVo7AN done, [913]
# https://open.spotify.com/track/2GGMabyHXnJmjY6CXhhB2e
# Song 2GGMabyHXnJmjY6CXhhB2e done, [914]
# https://open.spotify.com/track/2gwkD6igEhQbDQegRCcdoB
# Song 2gwkD6igEhQbDQegRCcdoB done, [915]
# https://open.spotify.com/track/3z4CGd63tpUn9a6oQSG0CI
# Song 3z4CGd63tpUn9a6oQSG0CI done, [916]
# https://open.spotify.com/track/7f5trao56t7sB7f14QDTmp
# Song 7f5trao56t7sB7f14QDTmp done, [917]
# https://open.spotify.com/track/0uI7yAKUf52Cn7y3sYyjiX
# Song 0uI7yAKUf52Cn7y3sYyjiX done, [918]
# https://open.spotify.com/track/5ry2OE6R2zPQFDO85XkgRb
# Song 5ry2OE6R2zPQFDO85XkgRb done, [919]
# https://open.spotify.com/track/6WrI0LAC5M1Rw2MnX2ZvEg
# Song 6WrI0LAC5M1Rw2MnX2ZvEg done, [920]
# https://open.spotify.com/track/0pEkK8MqbmGSX7fT8WLMbR
# Song 0pEkK8MqbmGSX7fT8WLMbR done, [944]
# https://open.spotify.com/track/2YpeDb67231RjR0MgVLzsG
# Song 2YpeDb67231RjR0MgVLzsG done, [945]
# https://open.spotify.com/track/2YpeDb67231RjR0MgVLzsG
# Song 2YpeDb67231RjR0MgVLzsG done, [946]
# https://open.spotify.com/track/1000nHvUdawXuUHgBod4Wv
# Song 1000nHvUdawXuUHgBod4Wv done, [947]
# https://open.spotify.com/track/1lOe9qE0vR9zwWQAOk6CoO
# Song 1lOe9qE0vR9zwWQAOk6CoO done, [948]
# https://open.spotify.com/track/3HWzoMvoF3TQfYg4UPszDq
# Song 3HWzoMvoF3TQfYg4UPszDq done, [949]
# https://open.spotify.com/track/6KgBpzTuTRPebChN0VTyzV
# Song 6KgBpzTuTRPebChN0VTyzV done, [950]
# https://open.spotify.com/track/4t9a07PAghtQMRAIP9FQ7Z
# Song 4t9a07PAghtQMRAIP9FQ7Z done, [951]
# https://open.spotify.com/track/6UnCGAEmrbGIOSmGRZQ1M2
# Song 6UnCGAEmrbGIOSmGRZQ1M2 done, [952]
# https://open.spotify.com/track/27rdGxbavYJeBphck5MZAF
# Song 27rdGxbavYJeBphck5MZAF done, [953]
# https://open.spotify.com/track/5icOoE6VgqFKohjWWNp0Ac
# Song 5icOoE6VgqFKohjWWNp0Ac done, [954]
# https://open.spotify.com/track/7gZXCjAy6nxKCQWLEeX4LZ
# Song 7gZXCjAy6nxKCQWLEeX4LZ done, [955]
# https://open.spotify.com/track/6iW38RGqdDGOofmz2HeXLW
# Song 6iW38RGqdDGOofmz2HeXLW done, [956]
# https://open.spotify.com/track/2IRZnDFmlqMuOrYOLnZZyc
# Song 2IRZnDFmlqMuOrYOLnZZyc done, [957]
# https://open.spotify.com/track/5N1o6d8zGcSZSeMFkOUQOk
# Song 5N1o6d8zGcSZSeMFkOUQOk done, [958]
# https://open.spotify.com/track/6QQtHdz4PNJWQX4nrAQGC9
# Song 6QQtHdz4PNJWQX4nrAQGC9 done, [959]
# https://open.spotify.com/track/3j84U36KvLeXNDPv4t5pI8
# Song 3j84U36KvLeXNDPv4t5pI8 done, [960]
# https://open.spotify.com/track/5OFlp1fOrfiSXOjw4wuSgy
# Song 5OFlp1fOrfiSXOjw4wuSgy done, [961]
# https://open.spotify.com/track/0rIAC4PXANcKmitJfoqmVm
# Song 0rIAC4PXANcKmitJfoqmVm done, [962]
# https://open.spotify.com/track/5Jqg1ta5RhBIYuJ1gdHCAt
# Song 5Jqg1ta5RhBIYuJ1gdHCAt done, [963]
# https://open.spotify.com/track/59ywHNwwchG4nZJMLyxSzd
# Song 59ywHNwwchG4nZJMLyxSzd done, [964]
# https://open.spotify.com/track/1rqqCSm0Qe4I9rUvWncaom
# Song 1rqqCSm0Qe4I9rUvWncaom done, [965]
# https://open.spotify.com/track/132ALUzVLmqYB4UsBj5qD6
# Song 132ALUzVLmqYB4UsBj5qD6 done, [966]
# https://open.spotify.com/track/6uFn47ACjqYkc0jADwEdj1
# Song 6uFn47ACjqYkc0jADwEdj1 done, [967]
# https://open.spotify.com/track/21jGcNKet2qwijlDFuPiPb
# Song 21jGcNKet2qwijlDFuPiPb done, [968]
# https://open.spotify.com/track/7dt6x5M1jzdTEt8oCbisTK
# Song 7dt6x5M1jzdTEt8oCbisTK done, [969]
# https://open.spotify.com/track/0RiRZpuVRbi7oqRdSMwhQY
# Song 0RiRZpuVRbi7oqRdSMwhQY done, [970]
# https://open.spotify.com/track/7xQAfvXzm3AkraOtGPWIZg
# Song 7xQAfvXzm3AkraOtGPWIZg done, [971]
# https://open.spotify.com/track/0t3ZvGKlmYmVsDzBJAXK8C
# Song 0t3ZvGKlmYmVsDzBJAXK8C done, [972]
# https://open.spotify.com/track/7tFiyTwD0nx5a1eklYtX2J
# Song 7tFiyTwD0nx5a1eklYtX2J done, [973]
# https://open.spotify.com/track/2tnVG71enUj33Ic2nFN6kZ
# Song 2tnVG71enUj33Ic2nFN6kZ done, [974]
# https://open.spotify.com/track/36orMWv2PgvnzXsd5CJ0yL
# Song 36orMWv2PgvnzXsd5CJ0yL done, [975]
# https://open.spotify.com/track/5KBARWIxeMGkvUax9VtVC9
# Song 5KBARWIxeMGkvUax9VtVC9 done, [976]
# https://open.spotify.com/track/4bTZeO72FwMa6wKOiqoynL
# Song 4bTZeO72FwMa6wKOiqoynL done, [977]
# https://open.spotify.com/track/6v3KW9xbzN5yKLt9YKDYA2
# Song 6v3KW9xbzN5yKLt9YKDYA2 done, [978]
# https://open.spotify.com/track/2bT1PH7Cw3J9p3t7nlXCdh
# Song 2bT1PH7Cw3J9p3t7nlXCdh done, [979]
# https://open.spotify.com/track/1ABvDz0JnQGO8M8NYjRNMp
# Song 1ABvDz0JnQGO8M8NYjRNMp done, [980]
# https://open.spotify.com/track/5DXKtoZLm31msT7tNGNHLG
# Song 5DXKtoZLm31msT7tNGNHLG done, [981]
# https://open.spotify.com/track/1dGr1c8CrMLDpV6mPbImSI
# Song 1dGr1c8CrMLDpV6mPbImSI done, [982]
# https://open.spotify.com/track/1BxfuPKGuaTgP7aM0Bbdwr
# Song 1BxfuPKGuaTgP7aM0Bbdwr done, [983]
# https://open.spotify.com/track/6RRNNciQGZEXnqk8SQ9yv5
# Song 6RRNNciQGZEXnqk8SQ9yv5 done, [984]
# https://open.spotify.com/track/2xLMifQCjDGFmkHkpNLD9h
# Song 2xLMifQCjDGFmkHkpNLD9h done, [985]
# https://open.spotify.com/track/5hVghJ4KaYES3BFUATCYn0
# Song 5hVghJ4KaYES3BFUATCYn0 done, [986]
# https://open.spotify.com/track/5X5YDBavdU5RjYMlxqwlCm
# Song 5X5YDBavdU5RjYMlxqwlCm done, [987]
# https://open.spotify.com/track/23GvTfcGK454ppLsts3W44
# Song 23GvTfcGK454ppLsts3W44 done, [988]
# https://open.spotify.com/track/3s4mrPrEFFPF0LmAfutW0n
# Song 3s4mrPrEFFPF0LmAfutW0n done, [989]
# ------------------------------
# # of Titles: 90
# # of Artists: 90
# # of Streams: 90

# %%
chunk9 = pd.DataFrame({'title': titles9, 'artist': artists9, 'streams': streams9})
display(chunk9)
chunk9.to_csv('chunk9_raw.csv', encoding = 'UTF-8', index=False)
# Out:
#                                         title              artist  \
# 0    break up with your girlfriend, i'm bored       Ariana Grande
# 1               boyfriend (with Social House)       Ariana Grande
# 2                                   On A Roll            Ashley O
# 3                                    Callaita           Bad Bunny
# 4                           MIA (feat. Drake)           Bad Bunny
# ..                                        ...                 ...
# 85                                 SICKO MODE        Travis Scott
# 86                                  EARFQUAKE  Tyler, The Creator
# 87                  Boasty (feat. Idris Elba)               Wiley
# 88                Strike a Pose (feat. Aitch)    Young T & Bugsey
# 89  The London (feat. J. Cole & Travis Scott)          Young Thug
#
#           streams
# 0   1,016,355,182
# 1     877,976,080
# 2     119,064,618
# 3   1,534,744,486
# 4   1,374,414,877
# ..            ...
# 85  2,260,795,689
# 86  1,092,188,072
# 87    171,625,826
# 88    133,345,785
# 89    754,787,209
#
# [90 rows x 3 columns]

# %%
raw0 = pd.read_csv("chunk_raw.csv", encoding = 'utf-8')
raw1 = pd.read_csv("chunk1_raw.csv", encoding = 'utf-8')
raw2 = pd.read_csv("chunk2_raw.csv", encoding = 'utf-8')
raw3 = pd.read_csv("chunk3_raw.csv", encoding = 'utf-8')
raw4 = pd.read_csv("chunk4_raw.csv", encoding = 'utf-8')
raw5 = pd.read_csv("chunk5_raw.csv", encoding = 'utf-8')
raw6 = pd.read_csv("chunk6_raw.csv", encoding = 'utf-8')
raw7 = pd.read_csv("chunk7_raw.csv", encoding = 'utf-8')
raw8 = pd.read_csv("chunk8_raw.csv", encoding = 'utf-8')
raw9 = pd.read_csv("chunk9_raw.csv", encoding = 'utf-8')

spotify = pd.concat([raw0, raw1, raw2, raw3, raw4, raw5, raw6, raw7, raw8, raw9], ignore_index=True)
spotify = spotify.drop(columns=["Unnamed: 3", "Unnamed: 4"])
display(spotify)
# Out:
#                                              title              artist  \
# 0                    STARSTRUKK (feat. Katy Perry)               3OH!3
# 1                      My First Kiss (feat. Ke$ha)               3OH!3
# 2                                  I Need A Dollar          Aloe Blacc
# 3    Airplanes (feat. Hayley Williams of Paramore)               B.o.B
# 4                Nothin' on You (feat. Bruno Mars)               B.o.B
# ..                                             ...                 ...
# 985                                     SICKO MODE        Travis Scott
# 986                                      EARFQUAKE  Tyler, The Creator
# 987                      Boasty (feat. Idris Elba)               Wiley
# 988                    Strike a Pose (feat. Aitch)    Young T & Bugsey
# 989      The London (feat. J. Cole & Travis Scott)          Young Thug
#
#            streams
# 0      160,363,103
# 1      126,408,708
# 2      282,228,422
# 3      843,380,081
# 4      684,014,150
# ..             ...
# 985  2,260,795,689
# 986  1,092,188,072
# 987    171,625,826
# 988    133,345,785
# 989    754,787,209
#
# [990 rows x 3 columns]

# %%
tophits.to_csv('top1000songs_2010s_raw.csv', encoding='UTF-8', index= False)
apisongs.to_csv('apitopsongs_2010s_raw.csv', encoding = 'UTF-8', index = False)
spotify.to_csv('topsongstreams_raw.csv', encoding='UTF-8', index = False)
